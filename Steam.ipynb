# %%
### Load CSV File

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Tabela:

# %%
data = pd.read_csv('steam_games.csv')
data.head(10)
# Out:
#                                                  url   types  \
# 0    https://store.steampowered.com/app/379720/DOOM/     app
# 1  https://store.steampowered.com/app/578080/PLAY...     app
# 2  https://store.steampowered.com/app/637090/BATT...     app
# 3    https://store.steampowered.com/app/221100/DayZ/     app
# 4  https://store.steampowered.com/app/8500/EVE_On...     app
# 5  https://store.steampowered.com/bundle/5699/Gra...  bundle
# 6  https://store.steampowered.com/app/601150/Devi...     app
# 7  https://store.steampowered.com/app/477160/Huma...     app
# 8  https://store.steampowered.com/app/644930/They...     app
# 9  https://store.steampowered.com/app/774241/Warh...     app
#
#                                          name  \
# 0                                        DOOM
# 1               PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                                  BATTLETECH
# 3                                        DayZ
# 4                                  EVE Online
# 5  Grand Theft Auto V: Premium Online Edition
# 6                             Devil May Cry 5
# 7                            Human: Fall Flat
# 8                           They Are Billions
# 9                        Warhammer: Chaosbane
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
# 5  Grand Theft Auto V: Premium Online Edition bundle
# 6  The ultimate Devil Hunter is back in style, in...
# 7  Human: Fall Flat is a quirky open-ended physic...
# 8  They Are Billions is a Steampunk strategy game...
# 9  In a world ravaged by war and dominated by mag...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
# 5                                                NaN
# 6  Very Positive,(408),- 87% of the 408 user revi...
# 7  Very Positive,(629),- 91% of the 629 user revi...
# 8  Very Positive,(192),- 83% of the 192 user revi...
# 9                                                NaN
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
# 5                                                NaN           NaN
# 6  Very Positive,(9,645),- 92% of the 9,645 user ...   Mar 7, 2019
# 7  Very Positive,(23,763),- 91% of the 23,763 use...  Jul 22, 2016
# 8  Very Positive,(12,127),- 85% of the 12,127 use...  Dec 12, 2017
# 9  Mixed,(904),- 44% of the 904 user reviews for ...  May 31, 2019
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
# 5       Rockstar North                           Rockstar Games
# 6     CAPCOM Co., Ltd.        CAPCOM Co., Ltd.,CAPCOM Co., Ltd.
# 7      No Brakes Games              Curve Digital,Curve Digital
# 8      Numantian Games          Numantian Games,Numantian Games
# 9         Eko Software    Bigben Interactive,Bigben Interactive
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
# 5                                                NaN
# 6  Action,Hack and Slash,Great Soundtrack,Demons,...
# 7  Funny,Multiplayer,Co-op,Puzzle,Physics,Local C...
# 8  Early Access,Base Building,Strategy,Zombies,Su...
# 9  RPG,Adventure,Hack and Slash,Action,Action RPG...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,Steam Achieve...
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
# 5  Single-player,Multi-player,Downloadable Conten...
# 6  Single-player,Online Multi-Player,Online Co-op...
# 7  Single-player,Online Multi-Player,Local Co-op,...
# 8  Single-player,Steam Achievements,Steam Trading...
# 9  Single-player,Multi-player,Co-op,Online Co-op,...
#
#                                            languages  achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...          54.0
# 1  English,Korean,Simplified Chinese,French,Germa...          37.0
# 2                      English,French,German,Russian         128.0
# 3  English,French,Italian,German,Spanish - Spain,...           NaN
# 4                      English,German,Russian,French           NaN
# 5  English, French, Italian, German, Spanish - Sp...           NaN
# 6  English,French,Italian,German,Spanish - Spain,...          51.0
# 7  English,French,German,Spanish - Spain,Russian,...          55.0
# 8  English,Spanish - Spain,French,German,Japanese...          34.0
# 9  English,French,Italian,German,Spanish - Spain,...          43.0
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
# 5                                   Action,Adventure
# 6                                             Action
# 7                                    Adventure,Indie
# 8                              Strategy,Early Access
# 9                               Action,Adventure,RPG
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
# 5                                                NaN
# 6   About This Game The Devil you know returns in...
# 7   About This Game  ***NEW "DARK" LEVEL AVAILABL...
# 8   About This Game  They Are Billions is a strat...
# 9   About This Game  “Keep your eyes on this one,...
#
#                                       mature_content  \
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6   Mature Content Description  The developers de...
# 7                                                NaN
# 8                                                NaN
# 9   Mature Content Description  The developers de...
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
# 5                                                NaN
# 6  Minimum:,OS:,WINDOWS® 7, 8.1, 10 (64-BIT Requi...
# 7  Minimum:,OS:,Windows XP/Vista/7/8/8.1/10 x86 a...
# 8  Minimum:,OS:,Windows 7, 8, 10 (32 and 64 bits)...
# 9  Minimum:,Requires a 64-bit processor and opera...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1  Recommended:,Requires a 64-bit processor and o...         $29.99
# 2  Recommended:,Requires a 64-bit processor and o...         $39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
# 5                                                NaN            NaN
# 6  Recommended:,OS:,WINDOWS® 7, 8.1, 10 (64-BIT R...         $59.99
# 7  Recommended:,OS:,Windows XP/Vista/7/8/8.1/10 x...         $14.99
# 8  Recommended:,OS:,Windows 7, 8, 10  (64 bits),P...         $29.99
# 9  Recommended:,Requires a 64-bit processor and o...         $49.99
#
#   discount_price
# 0         $14.99
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5         $35.18
# 6         $70.42
# 7         $17.58
# 8            NaN
# 9            NaN

# %% [markdown]
# # Quais jogos são grátis?

# %%
gratis = data[(data.original_price == 'Free')]
gratis
# Out:
#                                                      url types  \
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# 260    https://store.steampowered.com/app/223750/DCS_...   app
# 738    https://store.steampowered.com/app/1044200/Was...   app
# 801    https://store.steampowered.com/app/319630/Life...   app
# 1016   https://store.steampowered.com/app/345330/Eden...   app
# ...                                                  ...   ...
# 40208  https://store.steampowered.com/app/769810/Grav...   app
# 40209  https://store.steampowered.com/app/864710/Mast...   app
# 40669  https://store.steampowered.com/app/894440/Mast...   app
# 40723  https://store.steampowered.com/app/876590/Meti...   app
# 40731  https://store.steampowered.com/app/876440/The_...   app
#
#                                                   name  \
# 4                                           EVE Online
# 260                            DCS World Steam Edition
# 738                                 Wasteland Survival
# 801                        Life is Strange - Episode 1
# 1016                                       Eden Rising
# ...                                                ...
# 40208              Gravel Free car BMW X6 Trophy Truck
# 40209   Masters of Puzzle - Destruction by Thomas Cole
# 40669                      Masters of Puzzle - Belfast
# 40723                  Metis One - Original Soundtrack
# 40731  The Adventures of Elena Temple - Design Booklet
#
#                                             desc_snippet  \
# 4      EVE Online is a community-driven spaceship MMO...
# 260    Feel the excitement of flying the Su-25T "Frog...
# 738    Survive the post apocalypse in Wasteland Survi...
# 801    Episode 1 now FREE! Life is Strange is an awar...
# 1016   Brace yourself for a brand new action-packed O...
# ...                                                  ...
# 40208                                                NaN
# 40209                                                NaN
# 40669                                                NaN
# 40723                                                NaN
# 40731                                                NaN
#
#                                           recent_reviews  \
# 4      Mixed,(287),- 54% of the 287 user reviews in t...
# 260    Mostly Positive,(104),- 74% of the 104 user re...
# 738                                                  NaN
# 801    Very Positive,(552),- 91% of the 552 user revi...
# 1016                                                 NaN
# ...                                                  ...
# 40208                                                NaN
# 40209                                                NaN
# 40669                                                NaN
# 40723                                                NaN
# 40731                                                NaN
#
#                                              all_reviews  release_date  \
# 4      Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
# 260    Mostly Positive,(6,779),- 76% of the 6,779 use...  Mar 18, 2013
# 738    Mixed,(1,131),- 50% of the 1,131 user reviews ...   Jun 3, 2019
# 801    Overwhelmingly Positive,(123,683),- 96% of the...  Jan 29, 2015
# 1016   Mixed,(504),- 60% of the 504 user reviews for ...  May 17, 2019
# ...                                                  ...           ...
# 40208                                                NaN   Apr 4, 2018
# 40209                                                NaN  May 30, 2018
# 40669                                                NaN  Jul 10, 2018
# 40723                                                NaN   Jun 1, 2018
# 40731                                                NaN   Jun 4, 2018
#
#                                                developer  \
# 4                                                    CCP
# 260                                    Eagle Dynamics SA
# 738                                 Joyloft Co., Limited
# 801    DONTNOD Entertainment,Feral Interactive (Mac),...
# 1016                         Nvizzio Creations,Meridian4
# ...                                                  ...
# 40208                                   Milestone S.r.l.
# 40209                                      Belleal Games
# 40669                                      Belleal Games
# 40723                                     Actuator Games
# 40731                                          GrimTalin
#
#                                                publisher  \
# 4                                                CCP,CCP
# 260        The Fighter Collection,The Fighter Collection
# 738            Joyloft Co., Limited,Joyloft Co., Limited
# 801    Square Enix,Feral interactive (Mac),Feral Inte...
# 1016   The Wall Productions Inc.,The Wall Productions...
# ...                                                  ...
# 40208                  Milestone S.r.l.,Milestone S.r.l.
# 40209                        Belleal Games,Belleal Games
# 40669                        Belleal Games,Belleal Games
# 40723                                                NaN
# 40731                                                NaN
#
#                                             popular_tags  \
# 4      Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
# 260    Simulation,Flight,Free to Play,Military,Multip...
# 738    Free to Play,Survival,Multiplayer,Zombies,Adve...
# 801    Story Rich,Choices Matter,Great Soundtrack,Fem...
# 1016   Tower Defense,Adventure,Open World,Action,Stra...
# ...                                                  ...
# 40208                                      Racing,Sports
# 40209                            Indie,Casual,Simulation
# 40669                            Indie,Simulation,Casual
# 40723                            Action,Great Soundtrack
# 40731                                    Adventure,Indie
#
#                                             game_details  \
# 4      Multi-player,Online Multi-Player,MMO,Co-op,Onl...
# 260    Single-player,Multi-player,Captions available,...
# 738    Single-player,In-App Purchases,Steam is learni...
# 801    Single-player,Steam Achievements,Full controll...
# 1016   Single-player,Multi-player,Online Multi-Player...
# ...                                                  ...
# 40208  Single-player,Online Multi-Player,Downloadable...
# 40209  Single-player,Downloadable Content,Steam Achie...
# 40669  Single-player,Downloadable Content,Steam Achie...
# 40723  Single-player,Multi-player,Local Multi-Player,...
# 40731  Single-player,Downloadable Content,Steam Achie...
#
#                                                languages  achievements  \
# 4                          English,German,Russian,French           NaN
# 260    English,German,Spanish - Spain,Russian,Czech,F...           NaN
# 738                   English,Russian,Simplified Chinese           NaN
# 801    English,French,Italian,German,Spanish - Spain,...          60.0
# 1016   English,French,German,Spanish - Spain,Portugue...          26.0
# ...                                                  ...           ...
# 40208  English,French,Italian,German,Spanish - Spain,...           NaN
# 40209                                            English           NaN
# 40669                                            English           NaN
# 40723                                            English           NaN
# 40731                                            English           NaN
#
#                                                    genre  \
# 4      Action,Free to Play,Massively Multiplayer,RPG,...
# 260                              Free to Play,Simulation
# 738         Action,Adventure,Free to Play,RPG,Simulation
# 801                                     Action,Adventure
# 1016                     Action,Adventure,Indie,Strategy
# ...                                                  ...
# 40208                                      Racing,Sports
# 40209                            Casual,Indie,Simulation
# 40669                            Casual,Indie,Simulation
# 40723                                             Action
# 40731                                    Adventure,Indie
#
#                                         game_description mature_content  \
# 4                                      About This Game              NaN
# 260     About This Game Feel the excitement of flying...            NaN
# 738     About This Game  Wasteland Survival - Post Ap...            NaN
# 801     About This Game  Episode 1 now FREE! Life is ...            NaN
# 1016    About This Game  Eden Rising is a brand new a...            NaN
# ...                                                  ...            ...
# 40208   About This Content The European response to t...            NaN
# 40209   About This Content We present to you Destruct...            NaN
# 40669   About This Content We present to you Belfast ...            NaN
# 40723   About This Content Original Score for Metis O...            NaN
# 40731   About This Content Take a look inside the Des...            NaN
#
#                                     minimum_requirements  \
# 4      Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
# 260    Minimum system requirements (LOW graphics sett...
# 738                                                  NaN
# 801    Minimum:,OS:,Windows Vista,Processor:,Dual Cor...
# 1016   Minimum:,OS:,Windows 7 (64-bit),Processor:,Int...
# ...                                                  ...
# 40208  Minimum:,Requires a 64-bit processor and opera...
# 40209  Minimum:,Requires a 64-bit processor and opera...
# 40669  Minimum:,Requires a 64-bit processor and opera...
# 40723   Minimum:,OS:,Any,Storage:,500 MB available space
# 40731                                                NaN
#
#                                 recommended_requirements original_price  \
# 4      Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
# 260    Recommended system requirements (HIGH graphics...           Free
# 738                                                  NaN           Free
# 801    Recommended:,OS:,Windows 7,Processor:,Dual Cor...           Free
# 1016   Recommended:,OS:,Windows 10 (64-bit),Processor...           Free
# ...                                                  ...            ...
# 40208  Recommended:,Requires a 64-bit processor and o...           Free
# 40209  Recommended:,Requires a 64-bit processor and o...           Free
# 40669  Recommended:,Requires a 64-bit processor and o...           Free
# 40723  Recommended:,OS:,Any,Storage:,500 MB available...           Free
# 40731                                                NaN           Free
#
#       discount_price
# 4                NaN
# 260              NaN
# 738              NaN
# 801          $412.53
# 1016             NaN
# ...              ...
# 40208            NaN
# 40209            NaN
# 40669            NaN
# 40723            NaN
# 40731            NaN
#
# [1326 rows x 20 columns]

# %% [markdown]
# # Quantos jogos a base de dados tem?

# %%
df = pd.DataFrame(data)
quantidade_jogos = df[df.columns[0]].count()
quantidade_jogos
# Out:
# 40833

# %% [markdown]
# # Top 10 com a melhor review

# %% [markdown]
# Percentagem das Reviews

# %%
vals = []
for s in data.recent_reviews:
    valor = 0
    try:
        print(s)
        index = s.find('%')
       
    
        a=s[index -2]
        b=s[index -1]
        valor=str(a)+str(b)
    except:
        valor = 0
        
    print(valor)
    vals.append(valor)
# Out:
# Very Positive,(554),- 89% of the 554 user reviews in the last 30 days are positive.
# 89
# Mixed,(6,214),- 49% of the 6,214 user reviews in the last 30 days are positive.
# 49
# Mixed,(166),- 54% of the 166 user reviews in the last 30 days are positive.
# 54
# Mixed,(932),- 57% of the 932 user reviews in the last 30 days are positive.
# 57
# Mixed,(287),- 54% of the 287 user reviews in the last 30 days are positive.
# 54
# nan
# 0
# Very Positive,(408),- 87% of the 408 user reviews in the last 30 days are positive.
# 87
# Very Positive,(629),- 91% of the 629 user reviews in the last 30 days are positive.
# 91
# Very Positive,(192),- 83% of the 192 user reviews in the last 30 days are positive.
# 83
# nan
# 0
# Very Positive,(67),- 80% of the 67 user reviews in the last 30 days are positive.
# 80
# Very Positive,(78),- 82% of the 78 user reviews in the last 30 days are positive.
# 82
# Mixed,(76),- 63% of the 76 user reviews in the last 30 days are positive.
# 63
# Mixed,(33),- 51% of the 33 user reviews in the last 30 days are positive.
# 51
# Mixed,(66),- 40% of the 66 user reviews in the last 30 days are positive.
# 40
# nan
# 0
# Very Positive,(88),- 94% of the 88 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(56),- 71% of the 56 user reviews in the last 30 days are positive.
# 71
# Mixed,(91),- 49% of the 91 user reviews in the last 30 days are positive.
# 49
# Very Positive,(28),- 82% of the 28 user reviews in the last 30 days are positive.
# 82
# Mixed,(56),- 62% of the 56 user reviews in the last 30 days are positive.
# 62
# Very Positive,(47),- 95% of the 47 user reviews in the last 30 days are positive.
# 95
# nan
# 0
# Mixed,(206),- 65% of the 206 user reviews in the last 30 days are positive.
# 65
# Mixed,(303),- 66% of the 303 user reviews in the last 30 days are positive.
# 66
# nan
# 0
# Overwhelmingly Positive,(352),- 98% of the 352 user reviews in the last 30 days are positive.
# 98
# Very Positive,(61),- 91% of the 61 user reviews in the last 30 days are positive.
# 91
# Mixed,(61),- 68% of the 61 user reviews in the last 30 days are positive.
# 68
# Mostly Positive,(95),- 76% of the 95 user reviews in the last 30 days are positive.
# 76
# Mixed,(198),- 46% of the 198 user reviews in the last 30 days are positive.
# 46
# Very Positive,(413),- 91% of the 413 user reviews in the last 30 days are positive.
# 91
# Very Positive,(95),- 92% of the 95 user reviews in the last 30 days are positive.
# 92
# Very Positive,(148),- 93% of the 148 user reviews in the last 30 days are positive.
# 93
# Mostly Positive,(133),- 77% of the 133 user reviews in the last 30 days are positive.
# 77
# Very Positive,(153),- 91% of the 153 user reviews in the last 30 days are positive.
# 91
# Mixed,(40),- 62% of the 40 user reviews in the last 30 days are positive.
# 62
# Mostly Positive,(155),- 72% of the 155 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 72
# Very Positive,(52),- 88% of the 52 user reviews in the last 30 days are positive.
# 88
# nan
# 0
# Mixed,(25),- 64% of the 25 user reviews in the last 30 days are positive.
# 64
# nan
# 0
# Very Positive,(439),- 94% of the 439 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(51),- 76% of the 51 user reviews in the last 30 days are positive.
# 76
# nan
# 0
# Very Positive,(463),- 93% of the 463 user reviews in the last 30 days are positive.
# 93
# Very Positive,(77),- 97% of the 77 user reviews in the last 30 days are positive.
# 97
# Very Positive,(25),- 92% of the 25 user reviews in the last 30 days are positive.
# 92
# Mixed,(97),- 50% of the 97 user reviews in the last 30 days are positive.
# 50
# nan
# 0
# nan
# 0
# Mixed,(53),- 60% of the 53 user reviews in the last 30 days are positive.
# 60
# Mostly Positive,(29),- 72% of the 29 user reviews in the last 30 days are positive.
# 72
# Very Positive,(335),- 82% of the 335 user reviews in the last 30 days are positive.
# 82
# Mostly Positive,(264),- 77% of the 264 user reviews in the last 30 days are positive.
# 77
# Mostly Positive,(46),- 71% of the 46 user reviews in the last 30 days are positive.
# 71
# Mixed,(76),- 64% of the 76 user reviews in the last 30 days are positive.
# 64
# nan
# 0
# nan
# 0
# Mixed,(303),- 66% of the 303 user reviews in the last 30 days are positive.
# 66
# Very Positive,(60),- 85% of the 60 user reviews in the last 30 days are positive.
# 85
# Mostly Positive,(162),- 77% of the 162 user reviews in the last 30 days are positive.
# 77
# Mixed,(82),- 69% of the 82 user reviews in the last 30 days are positive.
# 69
# nan
# 0
# Mixed,(312),- 57% of the 312 user reviews in the last 30 days are positive.
# 57
# Mostly Positive,(562),- 75% of the 562 user reviews in the last 30 days are positive.
# 75
# nan
# 0
# Mixed,(105),- 66% of the 105 user reviews in the last 30 days are positive.
# 66
# nan
# 0
# Very Positive,(60),- 86% of the 60 user reviews in the last 30 days are positive.
# 86
# Very Positive,(20),- 80% of the 20 user reviews in the last 30 days are positive.
# 80
# Mostly Positive,(41),- 78% of the 41 user reviews in the last 30 days are positive.
# 78
# Overwhelmingly Positive,(150),- 99% of the 150 user reviews in the last 30 days are positive.
# 99
# Very Positive,(244),- 92% of the 244 user reviews in the last 30 days are positive.
# 92
# nan
# 0
# Mixed,(66),- 53% of the 66 user reviews in the last 30 days are positive.
# 53
# Very Positive,(87),- 87% of the 87 user reviews in the last 30 days are positive.
# 87
# Very Positive,(31),- 93% of the 31 user reviews in the last 30 days are positive.
# 93
# Very Positive,(165),- 86% of the 165 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Mostly Positive,(173),- 78% of the 173 user reviews in the last 30 days are positive.
# 78
# nan
# 0
# Mostly Positive,(359),- 76% of the 359 user reviews in the last 30 days are positive.
# 76
# Very Positive,(601),- 93% of the 601 user reviews in the last 30 days are positive.
# 93
# Very Positive,(100),- 84% of the 100 user reviews in the last 30 days are positive.
# 84
# Mixed,(32),- 46% of the 32 user reviews in the last 30 days are positive.
# 46
# nan
# 0
# Mixed,(100),- 54% of the 100 user reviews in the last 30 days are positive.
# 54
# nan
# 0
# Mixed,(1,488),- 61% of the 1,488 user reviews in the last 30 days are positive.
# 61
# nan
# 0
# Very Positive,(126),- 84% of the 126 user reviews in the last 30 days are positive.
# 84
# Very Positive,(290),- 81% of the 290 user reviews in the last 30 days are positive.
# 81
# Mostly Positive,(77),- 79% of the 77 user reviews in the last 30 days are positive.
# 79
# Very Positive,(124),- 94% of the 124 user reviews in the last 30 days are positive.
# 94
# Mixed,(906),- 56% of the 906 user reviews in the last 30 days are positive.
# 56
# Very Positive,(70),- 92% of the 70 user reviews in the last 30 days are positive.
# 92
# Very Positive,(67),- 94% of the 67 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(131),- 76% of the 131 user reviews in the last 30 days are positive.
# 76
# Very Positive,(11),- 81% of the 11 user reviews in the last 30 days are positive.
# 81
# Very Positive,(75),- 84% of the 75 user reviews in the last 30 days are positive.
# 84
# Very Positive,(455),- 82% of the 455 user reviews in the last 30 days are positive.
# 82
# nan
# 0
# Very Positive,(66),- 92% of the 66 user reviews in the last 30 days are positive.
# 92
# Mostly Positive,(87),- 72% of the 87 user reviews in the last 30 days are positive.
# 72
# nan
# 0
# nan
# 0
# Mostly Positive,(38),- 78% of the 38 user reviews in the last 30 days are positive.
# 78
# Very Positive,(42),- 80% of the 42 user reviews in the last 30 days are positive.
# 80
# Mixed,(102),- 60% of the 102 user reviews in the last 30 days are positive.
# 60
# Very Positive,(198),- 89% of the 198 user reviews in the last 30 days are positive.
# 89
# Mostly Positive,(205),- 72% of the 205 user reviews in the last 30 days are positive.
# 72
# Mostly Positive,(31),- 74% of the 31 user reviews in the last 30 days are positive.
# 74
# Mixed,(70),- 57% of the 70 user reviews in the last 30 days are positive.
# 57
# nan
# 0
# Very Positive,(66),- 93% of the 66 user reviews in the last 30 days are positive.
# 93
# nan
# 0
# Very Positive,(98),- 83% of the 98 user reviews in the last 30 days are positive.
# 83
# Very Positive,(32),- 87% of the 32 user reviews in the last 30 days are positive.
# 87
# nan
# 0
# nan
# 0
# Mixed,(240),- 61% of the 240 user reviews in the last 30 days are positive.
# 61
# Very Positive,(35),- 94% of the 35 user reviews in the last 30 days are positive.
# 94
# Mixed,(498),- 60% of the 498 user reviews in the last 30 days are positive.
# 60
# Mostly Positive,(359),- 73% of the 359 user reviews in the last 30 days are positive.
# 73
# Very Positive,(117),- 85% of the 117 user reviews in the last 30 days are positive.
# 85
# Mostly Positive,(135),- 79% of the 135 user reviews in the last 30 days are positive.
# 79
# Mixed,(63),- 50% of the 63 user reviews in the last 30 days are positive.
# 50
# Very Positive,(86),- 81% of the 86 user reviews in the last 30 days are positive.
# 81
# Mostly Positive,(56),- 73% of the 56 user reviews in the last 30 days are positive.
# 73
# Very Positive,(184),- 88% of the 184 user reviews in the last 30 days are positive.
# 88
# Mixed,(153),- 50% of the 153 user reviews in the last 30 days are positive.
# 50
# Mostly Positive,(86),- 77% of the 86 user reviews in the last 30 days are positive.
# 77
# nan
# 0
# Very Positive,(143),- 85% of the 143 user reviews in the last 30 days are positive.
# 85
# nan
# 0
# Mixed,(53),- 62% of the 53 user reviews in the last 30 days are positive.
# 62
# Mostly Positive,(116),- 73% of the 116 user reviews in the last 30 days are positive.
# 73
# Mostly Positive,(82),- 75% of the 82 user reviews in the last 30 days are positive.
# 75
# Overwhelmingly Positive,(141),- 100% of the 141 user reviews in the last 30 days are positive.
# 00
# Very Positive,(106),- 89% of the 106 user reviews in the last 30 days are positive.
# 89
# Very Positive,(165),- 93% of the 165 user reviews in the last 30 days are positive.
# 93
# Mixed,(176),- 56% of the 176 user reviews in the last 30 days are positive.
# 56
# nan
# 0
# Very Positive,(36),- 86% of the 36 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Mostly Positive,(39),- 74% of the 39 user reviews in the last 30 days are positive.
# 74
# Very Positive,(68),- 83% of the 68 user reviews in the last 30 days are positive.
# 83
# Very Positive,(51),- 80% of the 51 user reviews in the last 30 days are positive.
# 80
# Very Positive,(166),- 84% of the 166 user reviews in the last 30 days are positive.
# 84
# Mostly Positive,(107),- 79% of the 107 user reviews in the last 30 days are positive.
# 79
# Very Positive,(46),- 82% of the 46 user reviews in the last 30 days are positive.
# 82
# Very Positive,(34),- 82% of the 34 user reviews in the last 30 days are positive.
# 82
# Mixed,(346),- 58% of the 346 user reviews in the last 30 days are positive.
# 58
# Very Positive,(530),- 94% of the 530 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(23),- 78% of the 23 user reviews in the last 30 days are positive.
# 78
# Mixed,(1,308),- 64% of the 1,308 user reviews in the last 30 days are positive.
# 64
# Mostly Positive,(208),- 71% of the 208 user reviews in the last 30 days are positive.
# 71
# Mixed,(20),- 65% of the 20 user reviews in the last 30 days are positive.
# 65
# Mostly Positive,(89),- 75% of the 89 user reviews in the last 30 days are positive.
# 75
# Mixed,(132),- 62% of the 132 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 62
# Mostly Positive,(118),- 75% of the 118 user reviews in the last 30 days are positive.
# 75
# Very Positive,(285),- 83% of the 285 user reviews in the last 30 days are positive.
# 83
# nan
# 0
# Very Positive,(122),- 93% of the 122 user reviews in the last 30 days are positive.
# 93
# Mostly Positive,(241),- 70% of the 241 user reviews in the last 30 days are positive.
# 70
# Mixed,(382),- 66% of the 382 user reviews in the last 30 days are positive.
# 66
# Mostly Positive,(31),- 70% of the 31 user reviews in the last 30 days are positive.
# 70
# nan
# 0
# nan
# 0
# Mostly Positive,(121),- 76% of the 121 user reviews in the last 30 days are positive.
# 76
# Very Positive,(10),- 90% of the 10 user reviews in the last 30 days are positive.
# 90
# nan
# 0
# Very Positive,(68),- 86% of the 68 user reviews in the last 30 days are positive.
# 86
# Mixed,(52),- 51% of the 52 user reviews in the last 30 days are positive.
# 51
# Mixed,(527),- 65% of the 527 user reviews in the last 30 days are positive.
# 65
# Very Positive,(160),- 83% of the 160 user reviews in the last 30 days are positive.
# 83
# Mostly Positive,(112),- 76% of the 112 user reviews in the last 30 days are positive.
# 76
# Mostly Positive,(306),- 70% of the 306 user reviews in the last 30 days are positive.
# 70
# nan
# 0
# nan
# 0
# Very Positive,(90),- 92% of the 90 user reviews in the last 30 days are positive.
# 92
# Very Positive,(186),- 84% of the 186 user reviews in the last 30 days are positive.
# 84
# Mostly Positive,(53),- 79% of the 53 user reviews in the last 30 days are positive.
# 79
# Very Positive,(595),- 93% of the 595 user reviews in the last 30 days are positive.
# 93
# Very Positive,(58),- 93% of the 58 user reviews in the last 30 days are positive.
# 93
# Very Positive,(43),- 83% of the 43 user reviews in the last 30 days are positive.
# 83
# Very Positive,(126),- 92% of the 126 user reviews in the last 30 days are positive.
# 92
# Very Positive,(67),- 92% of the 67 user reviews in the last 30 days are positive.
# 92
# Very Positive,(2,036),- 93% of the 2,036 user reviews in the last 30 days are positive.
# 93
# Very Positive,(126),- 80% of the 126 user reviews in the last 30 days are positive.
# 80
# nan
# 0
# nan
# 0
# Very Positive,(565),- 88% of the 565 user reviews in the last 30 days are positive.
# 88
# Very Positive,(122),- 94% of the 122 user reviews in the last 30 days are positive.
# 94
# Very Positive,(15),- 93% of the 15 user reviews in the last 30 days are positive.
# 93
# Very Positive,(166),- 84% of the 166 user reviews in the last 30 days are positive.
# 84
# Overwhelmingly Positive,(197),- 95% of the 197 user reviews in the last 30 days are positive.
# 95
# Very Positive,(246),- 80% of the 246 user reviews in the last 30 days are positive.
# 80
# nan
# 0
# Mostly Positive,(538),- 76% of the 538 user reviews in the last 30 days are positive.
# 76
# Mostly Positive,(276),- 77% of the 276 user reviews in the last 30 days are positive.
# 77
# Mixed,(15),- 60% of the 15 user reviews in the last 30 days are positive.
# 60
# Very Positive,(534),- 93% of the 534 user reviews in the last 30 days are positive.
# 93
# nan
# 0
# Mostly Positive,(53),- 71% of the 53 user reviews in the last 30 days are positive.
# 71
# Very Positive,(56),- 82% of the 56 user reviews in the last 30 days are positive.
# 82
# Mostly Positive,(128),- 71% of the 128 user reviews in the last 30 days are positive.
# 71
# Mostly Positive,(176),- 75% of the 176 user reviews in the last 30 days are positive.
# 75
# Mixed,(76),- 42% of the 76 user reviews in the last 30 days are positive.
# 42
# nan
# 0
# Very Positive,(122),- 93% of the 122 user reviews in the last 30 days are positive.
# 93
# Mixed,(80),- 45% of the 80 user reviews in the last 30 days are positive.
# 45
# nan
# 0
# Very Positive,(221),- 94% of the 221 user reviews in the last 30 days are positive.
# 94
# Very Positive,(141),- 89% of the 141 user reviews in the last 30 days are positive.
# 89
# nan
# 0
# Very Positive,(456),- 81% of the 456 user reviews in the last 30 days are positive.
# 81
# nan
# 0
# Very Positive,(266),- 94% of the 266 user reviews in the last 30 days are positive.
# 94
# Mixed,(56),- 69% of the 56 user reviews in the last 30 days are positive.
# 69
# Very Positive,(104),- 90% of the 104 user reviews in the last 30 days are positive.
# 90
# Overwhelmingly Positive,(475),- 96% of the 475 user reviews in the last 30 days are positive.
# 96
# Mixed,(567),- 69% of the 567 user reviews in the last 30 days are positive.
# 69
# Mostly Positive,(373),- 79% of the 373 user reviews in the last 30 days are positive.
# 79
# Mostly Positive,(188),- 78% of the 188 user reviews in the last 30 days are positive.
# 78
# Mixed,(235),- 62% of the 235 user reviews in the last 30 days are positive.
# 62
# Very Positive,(443),- 90% of the 443 user reviews in the last 30 days are positive.
# 90
# Very Positive,(83),- 86% of the 83 user reviews in the last 30 days are positive.
# 86
# Very Positive,(58),- 89% of the 58 user reviews in the last 30 days are positive.
# 89
# nan
# 0
# nan
# 0
# Mixed,(485),- 66% of the 485 user reviews in the last 30 days are positive.
# 66
# Very Positive,(107),- 93% of the 107 user reviews in the last 30 days are positive.
# 93
# Mixed,(184),- 52% of the 184 user reviews in the last 30 days are positive.
# 52
# Overwhelmingly Positive,(377),- 97% of the 377 user reviews in the last 30 days are positive.
# 97
# Mixed,(148),- 63% of the 148 user reviews in the last 30 days are positive.
# 63
# nan
# 0
# Mostly Positive,(201),- 79% of the 201 user reviews in the last 30 days are positive.
# 79
# nan
# 0
# Mostly Positive,(23),- 78% of the 23 user reviews in the last 30 days are positive.
# 78
# nan
# 0
# Mixed,(114),- 61% of the 114 user reviews in the last 30 days are positive.
# 61
# Overwhelmingly Positive,(172),- 95% of the 172 user reviews in the last 30 days are positive.
# 95
# nan
# 0
# Mostly Positive,(82),- 74% of the 82 user reviews in the last 30 days are positive.
# 74
# Mostly Positive,(317),- 79% of the 317 user reviews in the last 30 days are positive.
# 79
# Very Positive,(674),- 94% of the 674 user reviews in the last 30 days are positive.
# 94
# Very Positive,(230),- 92% of the 230 user reviews in the last 30 days are positive.
# 92
# Mostly Positive,(46),- 76% of the 46 user reviews in the last 30 days are positive.
# 76
# nan
# 0
# Mixed,(307),- 67% of the 307 user reviews in the last 30 days are positive.
# 67
# Mixed,(198),- 66% of the 198 user reviews in the last 30 days are positive.
# 66
# Very Positive,(200),- 81% of the 200 user reviews in the last 30 days are positive.
# 81
# Very Positive,(100),- 82% of the 100 user reviews in the last 30 days are positive.
# 82
# Overwhelmingly Positive,(899),- 98% of the 899 user reviews in the last 30 days are positive.
# 98
# Very Positive,(369),- 91% of the 369 user reviews in the last 30 days are positive.
# 91
# Mixed,(196),- 66% of the 196 user reviews in the last 30 days are positive.
# 66
# Very Positive,(239),- 86% of the 239 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Mostly Positive,(104),- 74% of the 104 user reviews in the last 30 days are positive.
# 74
# nan
# 0
# Very Positive,(768),- 82% of the 768 user reviews in the last 30 days are positive.
# 82
# nan
# 0
# nan
# 0
# Mixed,(752),- 48% of the 752 user reviews in the last 30 days are positive.
# 48
# Very Positive,(59),- 89% of the 59 user reviews in the last 30 days are positive.
# 89
# Mostly Positive,(134),- 70% of the 134 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 70
# Very Positive,(225),- 86% of the 225 user reviews in the last 30 days are positive.
# 86
# Very Positive,(339),- 86% of the 339 user reviews in the last 30 days are positive.
# 86
# Very Positive,(164),- 89% of the 164 user reviews in the last 30 days are positive.
# 89
# Overwhelmingly Positive,(3,266),- 96% of the 3,266 user reviews in the last 30 days are positive.
# 96
# Mixed,(350),- 68% of the 350 user reviews in the last 30 days are positive.
# 68
# Overwhelmingly Positive,(1,396),- 97% of the 1,396 user reviews in the last 30 days are positive.
# 97
# Very Positive,(488),- 85% of the 488 user reviews in the last 30 days are positive.
# 85
# Very Positive,(52),- 96% of the 52 user reviews in the last 30 days are positive.
# 96
# Mostly Positive,(83),- 77% of the 83 user reviews in the last 30 days are positive.
# 77
# Mostly Positive,(60),- 75% of the 60 user reviews in the last 30 days are positive.
# 75
# nan
# 0
# Very Positive,(328),- 88% of the 328 user reviews in the last 30 days are positive.
# 88
# Very Positive,(291),- 94% of the 291 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(213),- 74% of the 213 user reviews in the last 30 days are positive.
# 74
# nan
# 0
# Mostly Positive,(442),- 70% of the 442 user reviews in the last 30 days are positive.
# 70
# nan
# 0
# Mostly Positive,(122),- 76% of the 122 user reviews in the last 30 days are positive.
# 76
# Very Positive,(687),- 94% of the 687 user reviews in the last 30 days are positive.
# 94
# Overwhelmingly Positive,(1,455),- 96% of the 1,455 user reviews in the last 30 days are positive.
# 96
# Very Positive,(697),- 82% of the 697 user reviews in the last 30 days are positive.
# 82
# Very Positive,(202),- 83% of the 202 user reviews in the last 30 days are positive.
# 83
# Mixed,(497),- 58% of the 497 user reviews in the last 30 days are positive.
# 58
# Very Positive,(60),- 83% of the 60 user reviews in the last 30 days are positive.
# 83
# Very Positive,(507),- 93% of the 507 user reviews in the last 30 days are positive.
# 93
# Very Positive,(378),- 82% of the 378 user reviews in the last 30 days are positive.
# 82
# Mostly Positive,(119),- 78% of the 119 user reviews in the last 30 days are positive.
# 78
# nan
# 0
# nan
# 0
# Mixed,(284),- 57% of the 284 user reviews in the last 30 days are positive.
# 57
# Very Positive,(312),- 92% of the 312 user reviews in the last 30 days are positive.
# 92
# Very Positive,(345),- 82% of the 345 user reviews in the last 30 days are positive.
# 82
# Very Positive,(71),- 81% of the 71 user reviews in the last 30 days are positive.
# 81
# nan
# 0
# Very Positive,(129),- 93% of the 129 user reviews in the last 30 days are positive.
# 93
# Very Positive,(418),- 88% of the 418 user reviews in the last 30 days are positive.
# 88
# Mostly Negative,(520),- 32% of the 520 user reviews in the last 30 days are positive.
# 32
# Mixed,(3,239),- 56% of the 3,239 user reviews in the last 30 days are positive.
# 56
# Overwhelmingly Positive,(655),- 97% of the 655 user reviews in the last 30 days are positive.
# 97
# Very Positive,(312),- 92% of the 312 user reviews in the last 30 days are positive.
# 92
# Very Positive,(1,076),- 91% of the 1,076 user reviews in the last 30 days are positive.
# 91
# Very Positive,(246),- 93% of the 246 user reviews in the last 30 days are positive.
# 93
# Mixed,(842),- 66% of the 842 user reviews in the last 30 days are positive.
# 66
# Overwhelmingly Positive,(461),- 95% of the 461 user reviews in the last 30 days are positive.
# 95
# Mostly Positive,(545),- 73% of the 545 user reviews in the last 30 days are positive.
# 73
# Very Positive,(308),- 86% of the 308 user reviews in the last 30 days are positive.
# 86
# Mixed,(263),- 67% of the 263 user reviews in the last 30 days are positive.
# 67
# Very Positive,(149),- 85% of the 149 user reviews in the last 30 days are positive.
# 85
# Very Positive,(87),- 87% of the 87 user reviews in the last 30 days are positive.
# 87
# Mixed,(235),- 61% of the 235 user reviews in the last 30 days are positive.
# 61
# Very Positive,(144),- 81% of the 144 user reviews in the last 30 days are positive.
# 81
# nan
# 0
# Very Positive,(2,026),- 80% of the 2,026 user reviews in the last 30 days are positive.
# 80
# nan
# 0
# Very Positive,(14),- 92% of the 14 user reviews in the last 30 days are positive.
# 92
# Mostly Positive,(276),- 74% of the 276 user reviews in the last 30 days are positive.
# 74
# nan
# 0
# Very Positive,(295),- 90% of the 295 user reviews in the last 30 days are positive.
# 90
# Mostly Positive,(274),- 71% of the 274 user reviews in the last 30 days are positive.
# 71
# Very Positive,(533),- 93% of the 533 user reviews in the last 30 days are positive.
# 93
# Very Positive,(162),- 88% of the 162 user reviews in the last 30 days are positive.
# 88
# Mostly Positive,(82),- 75% of the 82 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 75
# nan
# 0
# Mostly Positive,(478),- 78% of the 478 user reviews in the last 30 days are positive.
# 78
# Overwhelmingly Positive,(505),- 97% of the 505 user reviews in the last 30 days are positive.
# 97
# Very Positive,(110),- 82% of the 110 user reviews in the last 30 days are positive.
# 82
# Very Positive,(154),- 94% of the 154 user reviews in the last 30 days are positive.
# 94
# Very Positive,(3,125),- 94% of the 3,125 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(1,919),- 75% of the 1,919 user reviews in the last 30 days are positive.
# 75
# Mixed,(41),- 63% of the 41 user reviews in the last 30 days are positive.
# 63
# nan
# 0
# Mixed,(928),- 68% of the 928 user reviews in the last 30 days are positive.
# 68
# Very Positive,(15),- 86% of the 15 user reviews in the last 30 days are positive.
# 86
# Mostly Positive,(290),- 72% of the 290 user reviews in the last 30 days are positive.
# 72
# Very Positive,(182),- 80% of the 182 user reviews in the last 30 days are positive.
# 80
# Very Positive,(1,860),- 94% of the 1,860 user reviews in the last 30 days are positive.
# 94
# Very Positive,(220),- 82% of the 220 user reviews in the last 30 days are positive.
# 82
# Mostly Positive,(490),- 71% of the 490 user reviews in the last 30 days are positive.
# 71
# nan
# 0
# Very Positive,(880),- 92% of the 880 user reviews in the last 30 days are positive.
# 92
# nan
# 0
# Mixed,(81),- 69% of the 81 user reviews in the last 30 days are positive.
# 69
# nan
# 0
# Mostly Positive,(80),- 73% of the 80 user reviews in the last 30 days are positive.
# 73
# Mostly Positive,(450),- 72% of the 450 user reviews in the last 30 days are positive.
# 72
# Mixed,(85),- 57% of the 85 user reviews in the last 30 days are positive.
# 57
# nan
# 0
# Very Positive,(977),- 91% of the 977 user reviews in the last 30 days are positive.
# 91
# Mostly Positive,(348),- 70% of the 348 user reviews in the last 30 days are positive.
# 70
# Very Positive,(132),- 87% of the 132 user reviews in the last 30 days are positive.
# 87
# Very Positive,(111),- 90% of the 111 user reviews in the last 30 days are positive.
# 90
# nan
# 0
# Mostly Positive,(492),- 77% of the 492 user reviews in the last 30 days are positive.
# 77
# Mixed,(776),- 66% of the 776 user reviews in the last 30 days are positive.
# 66
# Very Positive,(387),- 81% of the 387 user reviews in the last 30 days are positive.
# 81
# Overwhelmingly Positive,(2,744),- 95% of the 2,744 user reviews in the last 30 days are positive.
# 95
# nan
# 0
# Very Positive,(416),- 88% of the 416 user reviews in the last 30 days are positive.
# 88
# nan
# 0
# Very Positive,(898),- 84% of the 898 user reviews in the last 30 days are positive.
# 84
# Mostly Positive,(727),- 79% of the 727 user reviews in the last 30 days are positive.
# 79
# Overwhelmingly Positive,(269),- 96% of the 269 user reviews in the last 30 days are positive.
# 96
# Mixed,(524),- 61% of the 524 user reviews in the last 30 days are positive.
# 61
# Overwhelmingly Positive,(519),- 96% of the 519 user reviews in the last 30 days are positive.
# 96
# Very Positive,(1,279),- 94% of the 1,279 user reviews in the last 30 days are positive.
# 94
# Mostly Positive,(932),- 73% of the 932 user reviews in the last 30 days are positive.
# 73
# Mostly Positive,(267),- 74% of the 267 user reviews in the last 30 days are positive.
# 74
# Very Positive,(493),- 80% of the 493 user reviews in the last 30 days are positive.
# 80
# nan
# 0
# Mostly Positive,(870),- 78% of the 870 user reviews in the last 30 days are positive.
# 78
# Very Positive,(924),- 86% of the 924 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Very Positive,(975),- 90% of the 975 user reviews in the last 30 days are positive.
# 90
# nan
# 0
# nan
# 0
# nan
# 0
# Very Positive,(803),- 90% of the 803 user reviews in the last 30 days are positive.
# 90
# Very Positive,(1,202),- 88% of the 1,202 user reviews in the last 30 days are positive.
# 88
# Very Positive,(3,526),- 91% of the 3,526 user reviews in the last 30 days are positive.
# 91
# Mixed,(467),- 68% of the 467 user reviews in the last 30 days are positive.
# 68
# nan
# 0
# Very Positive,(719),- 84% of the 719 user reviews in the last 30 days are positive.
# 84
# Mixed,(1,207),- 64% of the 1,207 user reviews in the last 30 days are positive.
# 64
# Mostly Positive,(2,667),- 76% of the 2,667 user reviews in the last 30 days are positive.
# 76
# Very Positive,(1,195),- 92% of the 1,195 user reviews in the last 30 days are positive.
# 92
# Mixed,(408),- 64% of the 408 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 64
# Mixed,(2,423),- 68% of the 2,423 user reviews in the last 30 days are positive.
# 68
# Very Positive,(836),- 86% of the 836 user reviews in the last 30 days are positive.
# 86
# Mostly Positive,(760),- 76% of the 760 user reviews in the last 30 days are positive.
# 76
# Very Positive,(452),- 91% of the 452 user reviews in the last 30 days are positive.
# 91
# Mixed,(391),- 66% of the 391 user reviews in the last 30 days are positive.
# 66
# Mostly Positive,(168),- 76% of the 168 user reviews in the last 30 days are positive.
# 76
# Mostly Positive,(346),- 79% of the 346 user reviews in the last 30 days are positive.
# 79
# nan
# 0
# Mixed,(263),- 66% of the 263 user reviews in the last 30 days are positive.
# 66
# nan
# 0
# Very Positive,(371),- 85% of the 371 user reviews in the last 30 days are positive.
# 85
# Mostly Positive,(706),- 70% of the 706 user reviews in the last 30 days are positive.
# 70
# Mostly Positive,(2,367),- 72% of the 2,367 user reviews in the last 30 days are positive.
# 72
# Mostly Positive,(4,352),- 78% of the 4,352 user reviews in the last 30 days are positive.
# 78
# Very Positive,(2,837),- 83% of the 2,837 user reviews in the last 30 days are positive.
# 83
# Mixed,(5,299),- 65% of the 5,299 user reviews in the last 30 days are positive.
# 65
# Overwhelmingly Positive,(2,386),- 96% of the 2,386 user reviews in the last 30 days are positive.
# 96
# nan
# 0
# Mostly Positive,(1,923),- 79% of the 1,923 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 79
# Mixed,(217),- 67% of the 217 user reviews in the last 30 days are positive.
# 67
# Very Positive,(2,190),- 88% of the 2,190 user reviews in the last 30 days are positive.,This product has experienced one or more periods of off-topic review activity.  Based on your preferences, the reviews within these periods have been excluded from this product's Review Score.
# 88
# Very Positive,(1,018),- 87% of the 1,018 user reviews in the last 30 days are positive.
# 87
# Very Positive,(4,583),- 82% of the 4,583 user reviews in the last 30 days are positive.
# 82
# nan
# 0
# Mostly Positive,(1,105),- 78% of the 1,105 user reviews in the last 30 days are positive.
# 78
# Mostly Positive,(7,804),- 73% of the 7,804 user reviews in the last 30 days are positive.
# 73
# nan
# 0
# Mixed,(797),- 68% of the 797 user reviews in the last 30 days are positive.
# 68
# Very Positive,(36,076),- 86% of the 36,076 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Very Positive,(186),- 91% of the 186 user reviews in the last 30 days are positive.
# 91
# nan
# 0
# Mixed,(43),- 62% of the 43 user reviews in the last 30 days are positive.
# 62
# Very Positive,(283),- 93% of the 283 user reviews in the last 30 days are positive.
# 93
# Mixed,(262),- 51% of the 262 user reviews in the last 30 days are positive.
# 51
# Mostly Positive,(128),- 76% of the 128 user reviews in the last 30 days are positive.
# 76
# Mixed,(13),- 69% of the 13 user reviews in the last 30 days are positive.
# 69
# Mixed,(22),- 59% of the 22 user reviews in the last 30 days are positive.
# 59
# Very Positive,(27),- 81% of the 27 user reviews in the last 30 days are positive.
# 81
# Mixed,(122),- 53% of the 122 user reviews in the last 30 days are positive.
# 53
# Very Positive,(16),- 100% of the 16 user reviews in the last 30 days are positive.
# 00
# Mostly Positive,(27),- 77% of the 27 user reviews in the last 30 days are positive.
# 77
# Mixed,(14),- 57% of the 14 user reviews in the last 30 days are positive.
# 57
# Mostly Negative,(633),- 27% of the 633 user reviews in the last 30 days are positive.
# 27
# Very Positive,(44),- 97% of the 44 user reviews in the last 30 days are positive.
# 97
# Mostly Positive,(30),- 76% of the 30 user reviews in the last 30 days are positive.
# 76
# nan
# 0
# nan
# 0
# nan
# 0
# Very Positive,(78),- 84% of the 78 user reviews in the last 30 days are positive.
# 84
# Mostly Positive,(14),- 78% of the 14 user reviews in the last 30 days are positive.
# 78
# nan
# 0
# nan
# 0
# Very Positive,(45),- 80% of the 45 user reviews in the last 30 days are positive.
# 80
# Mostly Positive,(215),- 77% of the 215 user reviews in the last 30 days are positive.
# 77
# nan
# 0
# Mostly Positive,(49),- 73% of the 49 user reviews in the last 30 days are positive.
# 73
# Very Positive,(28),- 85% of the 28 user reviews in the last 30 days are positive.
# 85
# Mixed,(12),- 66% of the 12 user reviews in the last 30 days are positive.
# 66
# Very Positive,(80),- 87% of the 80 user reviews in the last 30 days are positive.
# 87
# Mixed,(13),- 69% of the 13 user reviews in the last 30 days are positive.
# 69
# Mostly Positive,(69),- 75% of the 69 user reviews in the last 30 days are positive.
# 75
# nan
# 0
# Very Positive,(36),- 100% of the 36 user reviews in the last 30 days are positive.
# 00
# Mixed,(66),- 56% of the 66 user reviews in the last 30 days are positive.
# 56
# Mixed,(639),- 66% of the 639 user reviews in the last 30 days are positive.
# 66
# Very Positive,(58),- 93% of the 58 user reviews in the last 30 days are positive.
# 93
# Mixed,(218),- 60% of the 218 user reviews in the last 30 days are positive.
# 60
# Mostly Positive,(78),- 78% of the 78 user reviews in the last 30 days are positive.
# 78
# Very Positive,(474),- 88% of the 474 user reviews in the last 30 days are positive.
# 88
# Very Positive,(47),- 91% of the 47 user reviews in the last 30 days are positive.
# 91
# Mostly Positive,(82),- 73% of the 82 user reviews in the last 30 days are positive.
# 73
# nan
# 0
# Very Positive,(218),- 86% of the 218 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# nan
# 0
# Overwhelmingly Positive,(180),- 96% of the 180 user reviews in the last 30 days are positive.
# 96
# Very Positive,(11),- 90% of the 11 user reviews in the last 30 days are positive.
# 90
# nan
# 0
# Very Positive,(323),- 87% of the 323 user reviews in the last 30 days are positive.
# 87
# Mixed,(10),- 60% of the 10 user reviews in the last 30 days are positive.
# 60
# Mixed,(51),- 41% of the 51 user reviews in the last 30 days are positive.
# 41
# Overwhelmingly Positive,(100),- 95% of the 100 user reviews in the last 30 days are positive.
# 95
# Mostly Positive,(24),- 79% of the 24 user reviews in the last 30 days are positive.
# 79
# Very Positive,(29),- 96% of the 29 user reviews in the last 30 days are positive.
# 96
# nan
# 0
# Very Positive,(56),- 96% of the 56 user reviews in the last 30 days are positive.
# 96
# Mostly Positive,(13),- 76% of the 13 user reviews in the last 30 days are positive.
# 76
# nan
# 0
# Very Positive,(30),- 93% of the 30 user reviews in the last 30 days are positive.
# 93
# nan
# 0
# Very Positive,(58),- 89% of the 58 user reviews in the last 30 days are positive.
# 89
# nan
# 0
# nan
# 0
# Very Positive,(22),- 81% of the 22 user reviews in the last 30 days are positive.
# 81
# nan
# 0
# Very Positive,(71),- 98% of the 71 user reviews in the last 30 days are positive.
# 98
# Mostly Positive,(119),- 76% of the 119 user reviews in the last 30 days are positive.
# 76
# nan
# 0
# nan
# 0
# nan
# 0
# Very Positive,(59),- 91% of the 59 user reviews in the last 30 days are positive.
# 91
# Very Positive,(39),- 92% of the 39 user reviews in the last 30 days are positive.
# 92
# Mixed,(170),- 58% of the 170 user reviews in the last 30 days are positive.
# 58
# Very Positive,(69),- 82% of the 69 user reviews in the last 30 days are positive.
# 82
# Very Positive,(34),- 100% of the 34 user reviews in the last 30 days are positive.
# 00
# nan
# 0
# nan
# 0
# Overwhelmingly Positive,(553),- 96% of the 553 user reviews in the last 30 days are positive.
# 96
# nan
# 0
# Very Positive,(79),- 88% of the 79 user reviews in the last 30 days are positive.
# 88
# Mixed,(39),- 53% of the 39 user reviews in the last 30 days are positive.
# 53
# nan
# 0
# Very Positive,(23),- 91% of the 23 user reviews in the last 30 days are positive.
# 91
# Mixed,(81),- 66% of the 81 user reviews in the last 30 days are positive.
# 66
# nan
# 0
# Mixed,(88),- 69% of the 88 user reviews in the last 30 days are positive.
# 69
# Very Positive,(57),- 91% of the 57 user reviews in the last 30 days are positive.
# 91
# Very Positive,(38),- 84% of the 38 user reviews in the last 30 days are positive.
# 84
# Mixed,(19),- 42% of the 19 user reviews in the last 30 days are positive.
# 42
# Mixed,(12),- 66% of the 12 user reviews in the last 30 days are positive.
# 66
# Mostly Negative,(46),- 34% of the 46 user reviews in the last 30 days are positive.
# 34
# Mixed,(48),- 47% of the 48 user reviews in the last 30 days are positive.
# 47
# nan
# 0
# Very Positive,(82),- 91% of the 82 user reviews in the last 30 days are positive.
# 91
# Very Positive,(23),- 86% of the 23 user reviews in the last 30 days are positive.
# 86
# Very Positive,(160),- 93% of the 160 user reviews in the last 30 days are positive.
# 93
# Mixed,(39),- 69% of the 39 user reviews in the last 30 days are positive.
# 69
# Mixed,(16),- 68% of the 16 user reviews in the last 30 days are positive.
# 68
# Mixed,(70),- 52% of the 70 user reviews in the last 30 days are positive.
# 52
# Very Positive,(39),- 94% of the 39 user reviews in the last 30 days are positive.
# 94
# Very Positive,(137),- 92% of the 137 user reviews in the last 30 days are positive.
# 92
# Very Positive,(136),- 94% of the 136 user reviews in the last 30 days are positive.
# 94
# Very Positive,(89),- 98% of the 89 user reviews in the last 30 days are positive.
# 98
# Very Positive,(105),- 84% of the 105 user reviews in the last 30 days are positive.
# 84
# nan
# 0
# Very Positive,(37),- 83% of the 37 user reviews in the last 30 days are positive.
# 83
# Very Positive,(83),- 87% of the 83 user reviews in the last 30 days are positive.
# 87
# nan
# 0
# Very Positive,(44),- 90% of the 44 user reviews in the last 30 days are positive.
# 90
# nan
# 0
# nan
# 0
# nan
# 0
# Very Positive,(30),- 86% of the 30 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# nan
# 0
# Very Positive,(92),- 92% of the 92 user reviews in the last 30 days are positive.
# 92
# Very Positive,(95),- 90% of the 95 user reviews in the last 30 days are positive.
# 90
# nan
# 0
# Very Positive,(365),- 85% of the 365 user reviews in the last 30 days are positive.
# 85
# Very Positive,(884),- 94% of the 884 user reviews in the last 30 days are positive.
# 94
# Mixed,(16),- 56% of the 16 user reviews in the last 30 days are positive.
# 56
# nan
# 0
# Very Positive,(122),- 83% of the 122 user reviews in the last 30 days are positive.
# 83
# nan
# 0
# Overwhelmingly Positive,(128),- 96% of the 128 user reviews in the last 30 days are positive.
# 96
# Very Positive,(38),- 89% of the 38 user reviews in the last 30 days are positive.
# 89
# nan
# 0
# nan
# 0
# Very Positive,(73),- 83% of the 73 user reviews in the last 30 days are positive.
# 83
# Very Positive,(110),- 86% of the 110 user reviews in the last 30 days are positive.
# 86
# Very Positive,(28),- 82% of the 28 user reviews in the last 30 days are positive.
# 82
# nan
# 0
# Very Positive,(75),- 84% of the 75 user reviews in the last 30 days are positive.
# 84
# Mostly Positive,(62),- 70% of the 62 user reviews in the last 30 days are positive.
# 70
# nan
# 0
# Very Positive,(30),- 93% of the 30 user reviews in the last 30 days are positive.
# 93
# nan
# 0
# Mostly Positive,(195),- 71% of the 195 user reviews in the last 30 days are positive.
# 71
# Very Positive,(46),- 80% of the 46 user reviews in the last 30 days are positive.
# 80
# Mixed,(50),- 62% of the 50 user reviews in the last 30 days are positive.
# 62
# Very Positive,(12),- 100% of the 12 user reviews in the last 30 days are positive.
# 00
# nan
# 0
# Very Positive,(151),- 93% of the 151 user reviews in the last 30 days are positive.
# 93
# nan
# 0
# nan
# 0
# Very Positive,(85),- 83% of the 85 user reviews in the last 30 days are positive.
# 83
# Mixed,(55),- 67% of the 55 user reviews in the last 30 days are positive.
# 67
# Mixed,(97),- 59% of the 97 user reviews in the last 30 days are positive.
# 59
# Very Positive,(156),- 84% of the 156 user reviews in the last 30 days are positive.
# 84
# nan
# 0
# Mostly Negative,(19),- 31% of the 19 user reviews in the last 30 days are positive.
# 31
# Mixed,(42),- 50% of the 42 user reviews in the last 30 days are positive.
# 50
# Very Positive,(101),- 92% of the 101 user reviews in the last 30 days are positive.
# 92
# Mixed,(126),- 59% of the 126 user reviews in the last 30 days are positive.
# 59
# Mostly Positive,(38),- 78% of the 38 user reviews in the last 30 days are positive.
# 78
# Mixed,(34),- 61% of the 34 user reviews in the last 30 days are positive.
# 61
# Very Positive,(12),- 83% of the 12 user reviews in the last 30 days are positive.
# 83
# nan
# 0
# Very Positive,(21),- 85% of the 21 user reviews in the last 30 days are positive.
# 85
# Very Positive,(190),- 90% of the 190 user reviews in the last 30 days are positive.
# 90
# Mostly Positive,(87),- 79% of the 87 user reviews in the last 30 days are positive.
# 79
# Very Positive,(313),- 93% of the 313 user reviews in the last 30 days are positive.
# 93
# Very Positive,(47),- 89% of the 47 user reviews in the last 30 days are positive.
# 89
# Very Positive,(28),- 96% of the 28 user reviews in the last 30 days are positive.
# 96
# Very Positive,(314),- 86% of the 314 user reviews in the last 30 days are positive.
# 86
# Mostly Positive,(48),- 70% of the 48 user reviews in the last 30 days are positive.
# 70
# Mixed,(227),- 65% of the 227 user reviews in the last 30 days are positive.
# 65
# Very Positive,(90),- 93% of the 90 user reviews in the last 30 days are positive.
# 93
# Overwhelmingly Positive,(485),- 96% of the 485 user reviews in the last 30 days are positive.
# 96
# nan
# 0
# nan
# 0
# Overwhelmingly Positive,(235),- 96% of the 235 user reviews in the last 30 days are positive.
# 96
# Very Positive,(83),- 97% of the 83 user reviews in the last 30 days are positive.
# 97
# Mostly Positive,(42),- 73% of the 42 user reviews in the last 30 days are positive.
# 73
# Mixed,(27),- 59% of the 27 user reviews in the last 30 days are positive.
# 59
# nan
# 0
# Mostly Positive,(14),- 78% of the 14 user reviews in the last 30 days are positive.
# 78
# nan
# 0
# Mixed,(36),- 63% of the 36 user reviews in the last 30 days are positive.
# 63
# Very Positive,(170),- 91% of the 170 user reviews in the last 30 days are positive.
# 91
# Mostly Positive,(156),- 71% of the 156 user reviews in the last 30 days are positive.
# 71
# Very Positive,(35),- 94% of the 35 user reviews in the last 30 days are positive.
# 94
# Mixed,(55),- 65% of the 55 user reviews in the last 30 days are positive.
# 65
# nan
# 0
# Very Positive,(232),- 87% of the 232 user reviews in the last 30 days are positive.
# 87
# nan
# 0
# Mixed,(28),- 64% of the 28 user reviews in the last 30 days are positive.
# 64
# Very Positive,(91),- 81% of the 91 user reviews in the last 30 days are positive.
# 81
# nan
# 0
# Mixed,(40),- 40% of the 40 user reviews in the last 30 days are positive.
# 40
# nan
# 0
# Very Positive,(56),- 87% of the 56 user reviews in the last 30 days are positive.
# 87
# Very Positive,(87),- 82% of the 87 user reviews in the last 30 days are positive.
# 82
# Mostly Positive,(69),- 79% of the 69 user reviews in the last 30 days are positive.
# 79
# Mostly Positive,(151),- 73% of the 151 user reviews in the last 30 days are positive.
# 73
# nan
# 0
# Mixed,(619),- 51% of the 619 user reviews in the last 30 days are positive.
# 51
# Very Positive,(17),- 88% of the 17 user reviews in the last 30 days are positive.
# 88
# Overwhelmingly Positive,(404),- 95% of the 404 user reviews in the last 30 days are positive.
# 95
# Mixed,(25),- 60% of the 25 user reviews in the last 30 days are positive.
# 60
# Very Positive,(88),- 88% of the 88 user reviews in the last 30 days are positive.
# 88
# Mixed,(157),- 63% of the 157 user reviews in the last 30 days are positive.
# 63
# Very Positive,(58),- 82% of the 58 user reviews in the last 30 days are positive.
# 82
# Mostly Positive,(27),- 74% of the 27 user reviews in the last 30 days are positive.
# 74
# nan
# 0
# Very Positive,(80),- 95% of the 80 user reviews in the last 30 days are positive.
# 95
# Mixed,(22),- 50% of the 22 user reviews in the last 30 days are positive.
# 50
# Mostly Positive,(53),- 71% of the 53 user reviews in the last 30 days are positive.
# 71
# nan
# 0
# Very Positive,(19),- 84% of the 19 user reviews in the last 30 days are positive.
# 84
# nan
# 0
# Mostly Positive,(348),- 76% of the 348 user reviews in the last 30 days are positive.
# 76
# Very Positive,(107),- 91% of the 107 user reviews in the last 30 days are positive.
# 91
# Very Positive,(21),- 80% of the 21 user reviews in the last 30 days are positive.
# 80
# Mixed,(45),- 64% of the 45 user reviews in the last 30 days are positive.
# 64
# Very Positive,(75),- 84% of the 75 user reviews in the last 30 days are positive.
# 84
# Very Positive,(687),- 91% of the 687 user reviews in the last 30 days are positive.
# 91
# Mixed,(58),- 60% of the 58 user reviews in the last 30 days are positive.
# 60
# Very Positive,(34),- 82% of the 34 user reviews in the last 30 days are positive.
# 82
# nan
# 0
# nan
# 0
# Very Positive,(34),- 82% of the 34 user reviews in the last 30 days are positive.
# 82
# Very Positive,(11),- 100% of the 11 user reviews in the last 30 days are positive.
# 00
# Very Positive,(16),- 100% of the 16 user reviews in the last 30 days are positive.
# 00
# Very Positive,(124),- 87% of the 124 user reviews in the last 30 days are positive.
# 87
# Very Positive,(24),- 91% of the 24 user reviews in the last 30 days are positive.
# 91
# Mixed,(93),- 43% of the 93 user reviews in the last 30 days are positive.
# 43
# Mixed,(71),- 64% of the 71 user reviews in the last 30 days are positive.
# 64
# Mixed,(15),- 66% of the 15 user reviews in the last 30 days are positive.
# 66
# Very Positive,(24),- 95% of the 24 user reviews in the last 30 days are positive.
# 95
# Mostly Positive,(31),- 70% of the 31 user reviews in the last 30 days are positive.
# 70
# nan
# 0
# Very Positive,(142),- 92% of the 142 user reviews in the last 30 days are positive.
# 92
# Mixed,(28),- 42% of the 28 user reviews in the last 30 days are positive.
# 42
# Mixed,(32),- 62% of the 32 user reviews in the last 30 days are positive.
# 62
# Mixed,(85),- 67% of the 85 user reviews in the last 30 days are positive.
# 67
# Very Positive,(2,028),- 84% of the 2,028 user reviews in the last 30 days are positive.
# 84
# Very Positive,(37),- 86% of the 37 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Very Positive,(14),- 92% of the 14 user reviews in the last 30 days are positive.
# 92
# Mixed,(33),- 48% of the 33 user reviews in the last 30 days are positive.
# 48
# Very Positive,(43),- 88% of the 43 user reviews in the last 30 days are positive.
# 88
# Very Positive,(25),- 92% of the 25 user reviews in the last 30 days are positive.
# 92
# Very Positive,(111),- 88% of the 111 user reviews in the last 30 days are positive.
# 88
# Very Positive,(44),- 90% of the 44 user reviews in the last 30 days are positive.
# 90
# Mostly Positive,(12),- 75% of the 12 user reviews in the last 30 days are positive.
# 75
# Very Positive,(109),- 84% of the 109 user reviews in the last 30 days are positive.
# 84
# Very Positive,(125),- 93% of the 125 user reviews in the last 30 days are positive.
# 93
# Mixed,(32),- 68% of the 32 user reviews in the last 30 days are positive.
# 68
# Very Positive,(10),- 90% of the 10 user reviews in the last 30 days are positive.
# 90
# Mixed,(42),- 54% of the 42 user reviews in the last 30 days are positive.
# 54
# Very Positive,(34),- 82% of the 34 user reviews in the last 30 days are positive.
# 82
# Very Positive,(77),- 89% of the 77 user reviews in the last 30 days are positive.
# 89
# nan
# 0
# Mixed,(200),- 59% of the 200 user reviews in the last 30 days are positive.
# 59
# Very Positive,(73),- 86% of the 73 user reviews in the last 30 days are positive.
# 86
# nan
# 0
# Very Positive,(13),- 84% of the 13 user reviews in the last 30 days are positive.
# 84
# Mostly Positive,(14),- 71% of the 14 user reviews in the last 30 days are positive.
# 71
# nan
# 0
# nan
# 0
# Very Positive,(27),- 92% of the 27 user reviews in the last 30 days are positive.
# 92
# Mixed,(26),- 65% of the 26 user reviews in the last 30 days are positive.
# 65
# Mixed,(32),- 56% of the 32 user reviews in the last 30 days are positive.
# 56
# Very Positive,(18),- 83% of the 18 user reviews in the last 30 days are positive.
# 83
# ...
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# Mixed,(19),- 42% of the 19 user reviews in the last 30 days are positive.
# 42
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# Very Positive,(35),- 80% of the 35 user reviews in the last 30 days are positive.
# 80
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# Very Positive,(11),- 100% of the 11 user reviews in the last 30 days are positive.
# 00
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0
# nan
# 0

# %% [markdown]
# Cria uma nova coluna com os valores

# %%
data['Score'] = vals
data.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags  ...  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...  ...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...  ...
#
#                                            languages achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...         54.0
# 1  English,Korean,Simplified Chinese,French,Germa...         37.0
# 2                      English,French,German,Russian        128.0
# 3  English,French,Italian,German,Spanish - Spain,...          NaN
# 4                      English,German,Russian,French          NaN
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1  Recommended:,Requires a 64-bit processor and o...         $29.99
# 2  Recommended:,Requires a 64-bit processor and o...         $39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
#
#   discount_price Score
# 0         $14.99    89
# 1            NaN    49
# 2            NaN    54
# 3            NaN    57
# 4            NaN    54
#
# [5 rows x 21 columns]

# %% [markdown]
# Muda de objeto para float

# %% [markdown]
# Os 10 jogos com a melhor review

# %%
data.nlargest(n=10, columns=['Score'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17780/1304177780.py in <module>
# ----> 1 data.nlargest(n=10, columns=['Score'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    6634         Brunei      434000    12128      BN
#    6635         """
# -> 6636         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    6637
#    6638     def nsmallest(self, n, columns, keep: str = "first") -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1219     @final
#    1220     def nlargest(self):
# -> 1221         return self.compute("nlargest")
#    1222
#    1223     @final
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1349             dtype = frame[column].dtype
#    1350             if not self.is_valid_dtype_n_method(dtype):
# -> 1351                 raise TypeError(
#    1352                     f"Column {repr(column)} has dtype {dtype}, "
#    1353                     f"cannot use method {repr(method)} with this dtype"
#
# TypeError: Column 'Score' has dtype object, cannot use method 'nlargest' with this dtype

# %% [markdown]
# # Jogos em Português

# %%
portugues = data['languages'].str.contains('portuguese', case=False, na=False)
portugues

# %% [markdown]
# Calcular qual o maior numero da coluna

# %% [markdown]
# # Jogos para +18

# %%
maior_dezoito = data.dropna(subset=['mature_content'])
maior_dezoito.head()

# %% [markdown]
# # Pergunta: Qual género de jogos queres encontrar?

# %%
pergunta = input('Qual género preferes? ')

### Exemplo: Action ###

genero = data['popular_tags'].str.contains(pergunta, case=False, na=False)
data[genero]
# Out:
# Qual género preferes? Action
#                                                      url types  \
# 0        https://store.steampowered.com/app/379720/DOOM/   app
# 1      https://store.steampowered.com/app/578080/PLAY...   app
# 2      https://store.steampowered.com/app/637090/BATT...   app
# 3        https://store.steampowered.com/app/221100/DayZ/   app
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# ...                                                  ...   ...
# 40818  https://store.steampowered.com/app/903260/Air_...   app
# 40824  https://store.steampowered.com/app/906470/Gravia/   app
# 40825  https://store.steampowered.com/app/906460/Gala...   app
# 40826   https://store.steampowered.com/app/906430/Alive/   app
# 40831  https://store.steampowered.com/app/906635/Mega...   app
#
#                                 name  \
# 0                               DOOM
# 1      PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                         BATTLETECH
# 3                               DayZ
# 4                         EVE Online
# ...                              ...
# 40818    Air Threat - Small Donation
# 40824                         Gravia
# 40825                       Galactis
# 40826                          Alive
# 40831   Mega Man X5 Sound Collection
#
#                                             desc_snippet  \
# 0      Now includes all three premium DLC packs (Unto...
# 1      PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2      Take command of your own mercenary outfit of '...
# 3      The post-soviet country of Chernarus is struck...
# 4      EVE Online is a community-driven spaceship MMO...
# ...                                                  ...
# 40818                                                NaN
# 40824  The power of black holes in your hands. Gravia...
# 40825  Galactis is a single-player space shooter wher...
# 40826  Welcome to Alive , a Third person Cover based ...
# 40831                                                NaN
#
#                                           recent_reviews  \
# 0      Very Positive,(554),- 89% of the 554 user revi...
# 1      Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2      Mixed,(166),- 54% of the 166 user reviews in t...
# 3      Mixed,(932),- 57% of the 932 user reviews in t...
# 4      Mixed,(287),- 54% of the 287 user reviews in t...
# ...                                                  ...
# 40818                                                NaN
# 40824                                                NaN
# 40825                                                NaN
# 40826                                                NaN
# 40831                                                NaN
#
#                                              all_reviews  release_date  \
# 0      Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1      Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2      Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3      Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4      Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
# ...                                                  ...           ...
# 40818                                                NaN  Jul 13, 2018
# 40824                                                NaN     2019/2020
# 40825                                                NaN  Aug 15, 2018
# 40826                                                NaN  Jul 11, 2019
# 40831                                                NaN  Jul 24, 2018
#
#                  developer                                publisher  \
# 0              id Software    Bethesda Softworks,Bethesda Softworks
# 1         PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2      Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3      Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                      CCP                                  CCP,CCP
# ...                    ...                                      ...
# 40818            SharkGame                Garage Games,Garage Games
# 40824          Dan Goyette            Self-published,Self-published
# 40825    Gustavo Contreras      Gustavo Contreras,Gustavo Contreras
# 40826               OldGHZ                            OldGHZ,OldGHZ
# 40831      CAPCOM CO., LTD          CAPCOM CO., LTD,CAPCOM CO., LTD
#
#                                             popular_tags  ...  \
# 0      FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...
# 1      Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...
# 2      Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...
# 3      Survival,Zombies,Open World,Multiplayer,PvP,Ma...  ...
# 4      Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...  ...
# ...                                                  ...  ...
# 40818                                Action,Indie,Casual  ...
# 40824                                       Action,Indie  ...
# 40825                                       Action,Indie  ...
# 40826  Free to Play,Strategy,Action,RPG,Massively Mul...  ...
# 40831                                             Action  ...
#
#                                                languages achievements  \
# 0      English,French,Italian,German,Spanish - Spain,...         54.0
# 1      English,Korean,Simplified Chinese,French,Germa...         37.0
# 2                          English,French,German,Russian        128.0
# 3      English,French,Italian,German,Spanish - Spain,...          NaN
# 4                          English,German,Russian,French          NaN
# ...                                                  ...          ...
# 40818                                            English          NaN
# 40824                                            English          NaN
# 40825                                            English          NaN
# 40826                                            English          NaN
# 40831  English,French,Italian,German,Spanish - Spain,...          NaN
#
#                                                    genre  \
# 0                                                 Action
# 1                 Action,Adventure,Massively Multiplayer
# 2                              Action,Adventure,Strategy
# 3                 Action,Adventure,Massively Multiplayer
# 4      Action,Free to Play,Massively Multiplayer,RPG,...
# ...                                                  ...
# 40818                                Action,Casual,Indie
# 40824                                       Action,Indie
# 40825                                       Action,Indie
# 40826  Action,Free to Play,Massively Multiplayer,RPG,...
# 40831                                             Action
#
#                                         game_description  \
# 0       About This Game Developed by id software, the...
# 1       About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2       About This Game  From original BATTLETECH/Mec...
# 3       About This Game The post-soviet country of Ch...
# 4                                      About This Game
# ...                                                  ...
# 40818   About This Content This DLC is a donation for...
# 40824   About This Game Gravia puts the power of blac...
# 40825   About This Game Revive the glory of bygone sp...
# 40826   About This Game Alive is a multiplayer Third ...
# 40831   About This Content Get equipped with the stun...
#
#                                           mature_content  \
# 0                                                    NaN
# 1       Mature Content Description  The developers de...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40818                                                NaN
# 40824                                                NaN
# 40825                                                NaN
# 40826   Mature Content Description  The developers de...
# 40831                                                NaN
#
#                                     minimum_requirements  \
# 0      Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1      Minimum:,Requires a 64-bit processor and opera...
# 2      Minimum:,Requires a 64-bit processor and opera...
# 3      Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4      Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
# ...                                                  ...
# 40818  Minimum:,OS:,Windows XP,Processor:,Dual core,G...
# 40824                                                NaN
# 40825  Minimum:,OS:,Windows XP,Processor:,2GHz,Memory...
# 40826                                                NaN
# 40831  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
#
#                                 recommended_requirements original_price  \
# 0      Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1      Recommended:,Requires a 64-bit processor and o...         $29.99
# 2      Recommended:,Requires a 64-bit processor and o...         $39.99
# 3      Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4      Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
# ...                                                  ...            ...
# 40818  Recommended:,OS:,Windows 10,Processor:,QuadCor...          $1.99
# 40824                                                NaN            NaN
# 40825  Recommended:,OS:,Windows XP, Vista, 7, or 10,P...          $0.99
# 40826                                                NaN            NaN
# 40831  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
#
#       discount_price Score
# 0             $14.99    89
# 1                NaN    49
# 2                NaN    54
# 3                NaN    57
# 4                NaN    54
# ...              ...   ...
# 40818            NaN     0
# 40824            NaN     0
# 40825            NaN     0
# 40826            NaN     0
# 40831            NaN     0
#
# [16179 rows x 21 columns]

# %% [markdown]
# # Pergunta: Encontrar jogos de determinado Desenvolvedor

# %%
pergunta = input('De qual developer queres os jogos?: ')

### Exemplo de desenvolvedor: Bethesda ###

developer = data['developer'].str.contains(pergunta, case=False, na=False)
data[developer]
# Out:
# De qual developer queres os jogos?: Bethesda
#                                                      url types  \
# 164    https://store.steampowered.com/app/22330/The_E...   app
# 202    https://store.steampowered.com/app/611660/Fall...   app
# 211    https://store.steampowered.com/app/900883/The_...   app
# 337    https://store.steampowered.com/app/611670/The_...   app
# 403           https://store.steampowered.com/sub/199943/   sub
# 404    https://store.steampowered.com/app/489830/The_...   app
# 405    https://store.steampowered.com/app/377160/Fall...   app
# 756    https://store.steampowered.com/app/22320/The_E...   app
# 805    https://store.steampowered.com/app/588430/Fall...   app
# 837    https://store.steampowered.com/app/22370/Fallo...   app
# 1159   https://store.steampowered.com/app/22300/Fallo...   app
# 8037   https://store.steampowered.com/app/22410/Fallo...   app
# 9112   https://store.steampowered.com/app/435881/Fall...   app
# 11622  https://store.steampowered.com/app/22440/Fallo...   app
# 11623  https://store.steampowered.com/app/22420/Fallo...   app
# 20179  https://store.steampowered.com/app/22430/Fallo...   app
# 21478  https://store.steampowered.com/app/435870/Fall...   app
# 27056  https://store.steampowered.com/app/490650/Fall...   app
# 27163  https://store.steampowered.com/app/540810/Fall...   app
# 29208  https://store.steampowered.com/app/480630/Fall...   app
# 29386  https://store.steampowered.com/app/404090/Fall...   app
# 37388  https://store.steampowered.com/app/461150/Fall...   app
# 39430  https://store.steampowered.com/app/598120/The_...   app
# 40460  https://store.steampowered.com/app/598110/Fall...   app
#
#                                                     name  \
# 164    The Elder Scrolls IV: Oblivion® Game of the Ye...
# 202                                         Fallout 4 VR
# 211    The Elder Scrolls IV: Oblivion® Game of the Ye...
# 337                       The Elder Scrolls V: Skyrim VR
# 403                  Fallout 4: Game of the Year Edition
# 404          The Elder Scrolls V: Skyrim Special Edition
# 405                                            Fallout 4
# 756    The Elder Scrolls III: Morrowind® Game of the ...
# 805                                      Fallout Shelter
# 837                  Fallout 3: Game of the Year Edition
# 1159                                           Fallout 3
# 8037                            Fallout 3 - Broken Steel
# 9112                                Fallout 4 Far Harbor
# 11622                          Fallout 3 - Point Lookout
# 11623                               Fallout 3 - The Pitt
# 20179                        Fallout 3 - Mothership Zeta
# 21478                             Fallout 4 - Automatron
# 27056                               Fallout 4 Nuka-World
# 27163           Fallout 4 - High Resolution Texture Pack
# 29208                  Fallout 4 - Contraptions Workshop
# 29386                              Fallout 4 Season Pass
# 37388                             Fallout 3 - Soundtrack
# 39430  The Elder Scrolls V: Skyrim Special Edition - ...
# 40460                          Fallout 4 - Creation Club
#
#                                             desc_snippet  \
# 164    The Elder Scrolls IV: Oblivion® Game of the Ye...
# 202    Fallout 4, the legendary post-apocalyptic adve...
# 211    The Elder Scrolls IV: Oblivion® Game of the Ye...
# 337    A true, full-length open-world game for VR has...
# 403           Fallout 4: Game of the Year Edition bundle
# 404    Winner of more than 200 Game of the Year Award...
# 405    Bethesda Game Studios, the award-winning creat...
# 756    The Elder Scrolls III: Morrowind® Game of the ...
# 805    Fallout Shelter puts you in control of a state...
# 837    Prepare for the Future™ With Fallout 3: Game o...
# 1159   Vault-Tec engineers have worked around the clo...
# 8037                                                 NaN
# 9112                                                 NaN
# 11622                                                NaN
# 11623                                                NaN
# 20179                                                NaN
# 21478                                                NaN
# 27056                                                NaN
# 27163                                                NaN
# 29208                                                NaN
# 29386                                                NaN
# 37388                                                NaN
# 39430                                                NaN
# 40460                                                NaN
#
#                                           recent_reviews  \
# 164    Very Positive,(122),- 93% of the 122 user revi...
# 202    Mixed,(15),- 60% of the 15 user reviews in the...
# 211    Very Positive,(122),- 93% of the 122 user revi...
# 337    Mixed,(41),- 63% of the 41 user reviews in the...
# 403                                                  NaN
# 404    Very Positive,(371),- 85% of the 371 user revi...
# 405    Mostly Positive,(706),- 70% of the 706 user re...
# 756    Very Positive,(67),- 91% of the 67 user review...
# 805    Very Positive,(392),- 87% of the 392 user revi...
# 837    Mixed,(142),- 51% of the 142 user reviews in t...
# 1159   Mixed,(82),- 65% of the 82 user reviews in the...
# 8037                                                 NaN
# 9112   Very Positive,(13),- 84% of the 13 user review...
# 11622                                                NaN
# 11623                                                NaN
# 20179                                                NaN
# 21478  Mostly Positive,(18),- 77% of the 18 user revi...
# 27056  Mixed,(22),- 40% of the 22 user reviews in the...
# 27163  Mostly Negative,(26),- 23% of the 26 user revi...
# 29208                                                NaN
# 29386  Mostly Negative,(12),- 33% of the 12 user revi...
# 37388                                                NaN
# 39430                                                NaN
# 40460                                                NaN
#
#                                              all_reviews  release_date  \
# 164    Very Positive,(11,784),- 94% of the 11,784 use...  Sep 11, 2007
# 202    Mostly Positive,(2,407),- 70% of the 2,407 use...  Dec 11, 2017
# 211                                                  NaN  Jun 16, 2009
# 337    Very Positive,(2,137),- 80% of the 2,137 user ...   Apr 2, 2018
# 403                                                  NaN           NaN
# 404    Very Positive,(14,443),- 83% of the 14,443 use...  Oct 27, 2016
# 405    Mostly Positive,(90,387),- 70% of the 90,387 u...   Nov 9, 2015
# 756    Very Positive,(7,753),- 94% of the 7,753 user ...  Apr 29, 2002
# 805    Very Positive,(25,473),- 85% of the 25,473 use...  Mar 29, 2017
# 837    Mostly Positive,(17,673),- 78% of the 17,673 u...  Oct 13, 2009
# 1159   Mostly Positive,(10,799),- 77% of the 10,799 u...  Oct 28, 2008
# 8037   Very Positive,(82),- 82% of the 82 user review...  Jul 16, 2010
# 9112   Very Positive,(1,940),- 84% of the 1,940 user ...  May 18, 2016
# 11622  Positive,(40),- 85% of the 40 user reviews for...  Jul 16, 2010
# 11623  Positive,(35),- 88% of the 35 user reviews for...  Jul 16, 2010
# 20179  Mostly Positive,(50),- 74% of the 50 user revi...  Jul 16, 2010
# 21478  Mostly Positive,(2,079),- 75% of the 2,079 use...  Mar 21, 2016
# 27056  Mixed,(1,761),- 49% of the 1,761 user reviews ...  Aug 29, 2016
# 27163  Mixed,(2,073),- 49% of the 2,073 user reviews ...   Feb 6, 2017
# 29208  Mostly Negative,(1,022),- 38% of the 1,022 use...  Jun 20, 2016
# 29386  Mostly Negative,(2,337),- 34% of the 2,337 use...  Mar 21, 2016
# 37388                                                NaN  Jun 21, 2018
# 39430                                                NaN  Sep 25, 2017
# 40460                                                NaN  Aug 24, 2017
#
#                     developer                              publisher  \
# 164     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 202     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 211    Bethesda Game Studios®  Bethesda Softworks,Bethesda Softworks
# 337     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 403     Bethesda Game Studios                     Bethesda Softworks
# 404     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 405     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 756     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 805     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 837     Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 1159    Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 8037    Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 9112    Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 11622   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 11623   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 20179   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 21478   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 27056   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 27163   Bethesda Game Studios                                    NaN
# 29208   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 29386   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 37388   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 39430   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
# 40460   Bethesda Game Studios  Bethesda Softworks,Bethesda Softworks
#
#                                             popular_tags  ...  \
# 164    Open World,RPG,Fantasy,Singleplayer,Moddable,F...  ...
# 202    VR,Open World,Post-apocalyptic,RPG,Singleplaye...  ...
# 211    Open World,RPG,Fantasy,Singleplayer,Moddable,F...  ...
# 337    RPG,Open World,VR,Singleplayer,Adventure,Fanta...  ...
# 403                                                  NaN  ...
# 404    Open World,RPG,Adventure,Singleplayer,Fantasy,...  ...
# 405    Open World,Post-apocalyptic,Exploration,Single...  ...
# 756    RPG,Open World,Fantasy,Classic,Great Soundtrac...  ...
# 805    Free to Play,Survival,Base Building,Post-apoca...  ...
# 837    Open World,RPG,Post-apocalyptic,Singleplayer,M...  ...
# 1159   Open World,Post-apocalyptic,RPG,Singleplayer,E...  ...
# 8037                      RPG,Post-apocalyptic,Adventure  ...
# 9112   RPG,Open World,Post-apocalyptic,Singleplayer,S...  ...
# 11622                  RPG,Post-apocalyptic,Lovecraftian  ...
# 11623                               RPG,Post-apocalyptic  ...
# 20179                        RPG,Post-apocalyptic,Sci-fi  ...
# 21478  RPG,Robots,Post-apocalyptic,Open World,Action,...  ...
# 27056  RPG,Open World,Singleplayer,Post-apocalyptic,F...  ...
# 27163  RPG,FPS,Open World,Post-apocalyptic,Survival,S...  ...
# 29208  RPG,Post-apocalyptic,Sandbox,Open World,Buildi...  ...
# 29386  Open World,RPG,Post-apocalyptic,Singleplayer,A...  ...
# 37388                                                RPG  ...
# 39430  Psychological Horror,Horror,Dark Humor,Memes,D...  ...
# 40460  Psychological Horror,Horror,Dark Humor,Memes,C...  ...
#
#                                                languages achievements  \
# 164                                              English          NaN
# 202    English,French,Italian,German,Spanish - Spain,...         50.0
# 211                                              English          NaN
# 337    English,French,Italian,German,Spanish - Spain,...         75.0
# 403    English, French, Italian, German, Spanish - Sp...          NaN
# 404    English,French,Italian,German,Spanish - Spain,...         75.0
# 405    English,French,Italian,German,Spanish - Spain,...         84.0
# 756                                English,French,German          NaN
# 805    English,French,Italian,German,Spanish - Spain,...         35.0
# 837        English,French,German,Italian,Spanish - Spain          NaN
# 1159       English,French,Italian,German,Spanish - Spain          NaN
# 8037       English,French,German,Italian,Spanish - Spain          NaN
# 9112   English,French,Italian,German,Spanish - Spain,...          NaN
# 11622      English,French,German,Italian,Spanish - Spain          NaN
# 11623      English,French,German,Italian,Spanish - Spain          NaN
# 20179      English,French,German,Italian,Spanish - Spain          NaN
# 21478  English,French,Italian,German,Spanish - Spain,...          NaN
# 27056  English,French,Italian,German,Spanish - Spain,...          NaN
# 27163  English,French,Italian,German,Spanish - Spain,...          NaN
# 29208  English,French,Italian,German,Spanish - Spain,...          NaN
# 29386  English,French,Italian,German,Spanish - Spain,...          NaN
# 37388      English,French,Italian,German,Spanish - Spain          NaN
# 39430  English,French,Italian,German,Spanish - Spain,...          NaN
# 40460  English,French,Italian,German,Spanish - Spain,...          NaN
#
#                              genre  \
# 164                            RPG
# 202                            RPG
# 211                            NaN
# 337                            RPG
# 403                            RPG
# 404                            RPG
# 405                            RPG
# 756                            RPG
# 805    Free to Play,RPG,Simulation
# 837                            RPG
# 1159                           RPG
# 8037                           RPG
# 9112                           RPG
# 11622                          RPG
# 11623                          RPG
# 20179                          RPG
# 21478                          RPG
# 27056                          RPG
# 27163                          RPG
# 29208                          RPG
# 29386                          RPG
# 37388                          RPG
# 39430                          RPG
# 40460                          RPG
#
#                                         game_description  \
# 164     About This Game The Elder Scrolls IV: Oblivio...
# 202     About This Game Fallout 4, the legendary post...
# 211     About This Game The Elder Scrolls IV: Oblivio...
# 337     About This Game A true, full-length open-worl...
# 403                                                  NaN
# 404     About This Game Winner of more than 200 Game ...
# 405     About This Game Bethesda Game Studios, the aw...
# 756     About This Game The Elder Scrolls III: Morrow...
# 805     About This Game Fallout Shelter puts you in c...
# 837     About This Game  Prepare for the Future™ With...
# 1159    About This Game Vault-Tec engineers have work...
# 8037    About This Content  You may have dealt the En...
# 9112    About This Content A new case from Valentine’...
# 11622   About This Content Buy a ticket and hop onboa...
# 11623   About This Content  Explore a sprawling settl...
# 20179   About This Content  Defy hostile alien abduct...
# 21478   About This Content The mysterious Mechanist h...
# 27056   About This Content Take a trip to Nuka-World,...
# 27163   About This Content Experience the wasteland l...
# 29208   About This Content Machines that sort! Machin...
# 29386   About This Content We’ve always done a lot of...
# 37388   About This Content Tracklist:  01 - Main Titl...
# 39430   About This Content Get Credits to be used in ...
# 40460   About This Content Get Credits to be used in ...
#
#                                           mature_content  \
# 164                                                  NaN
# 202                                                  NaN
# 211                                                  NaN
# 337                                                  NaN
# 403                                                  NaN
# 404     Mature Content Description  The developers de...
# 405                                                  NaN
# 756                                                  NaN
# 805                                                  NaN
# 837                                                  NaN
# 1159                                                 NaN
# 8037                                                 NaN
# 9112                                                 NaN
# 11622                                                NaN
# 11623                                                NaN
# 20179                                                NaN
# 21478                                                NaN
# 27056                                                NaN
# 27163                                                NaN
# 29208                                                NaN
# 29386                                                NaN
# 37388                                                NaN
# 39430   Mature Content Description  The developers de...
# 40460                                                NaN
#
#                                     minimum_requirements  \
# 164                                                  NaN
# 202    Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 211                                                  NaN
# 337    Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 403                                                  NaN
# 404    Minimum:,OS:,Windows 7/8.1/10 (64-bit Version)...
# 405    Minimum:,Requires a 64-bit processor and opera...
# 756                                                  NaN
# 805    Minimum:,Requires a 64-bit processor and opera...
# 837    Minimum:,Operating system:,Windows XP/Vista,Pr...
# 1159   Minimum:,Operating system:,Windows XP/Vista,Pr...
# 8037   Minimum:,Operating system:,Windows XP/Vista,Pr...
# 9112   Minimum:,OS:,Windows 7/8/10 (64-bit OS require...
# 11622  Minimum:,Operating system:,Windows XP/Vista,Pr...
# 11623  Minimum:,Operating system:,Windows XP/Vista,Pr...
# 20179  Minimum:,Operating system:,Windows XP/Vista,Pr...
# 21478  Minimum:,OS:,Windows 7/8/10 (64-bit OS require...
# 27056  Minimum:,OS:,Windows 7/8/10 (64-bit OS require...
# 27163                                                NaN
# 29208  Minimum:,OS:,Windows 7/8/10 (64-bit OS require...
# 29386                                                NaN
# 37388  Minimum:,Operating system:,Windows XP/Vista,Pr...
# 39430  Minimum:,OS:,Windows 7/8.1/10 (64-bit Version)...
# 40460  Minimum:,OS:,Windows 7/8/10 (64-bit OS require...
#
#                                 recommended_requirements original_price  \
# 164                                                  NaN         $14.99
# 202    Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $59.99
# 211                                                  NaN         $19.99
# 337    Recommended:,OS:,Windows 10 (64-bit),Processor...         $59.99
# 403                                                  NaN         $59.99
# 404    Recommended:,OS:,Windows 7/8.1/10 (64-bit Vers...         $39.99
# 405    Recommended:,Requires a 64-bit processor and o...         $29.99
# 756                                                  NaN         $14.99
# 805    Recommended:,Requires a 64-bit processor and o...   Free to Play
# 837    Recommended:,Operating system:,Windows XP/Vist...         $19.99
# 1159   Recommended:,Operating system:,Windows XP/Vist...          $9.99
# 8037   Recommended:,Operating system:,Windows XP/Vist...          $4.99
# 9112   Recommended:,OS:,Windows 7/8/10 (64-bit OS req...         $24.99
# 11622  Recommended:,Operating system:,Windows XP/Vist...          $4.99
# 11623  Recommended:,Operating system:,Windows XP/Vist...          $4.99
# 20179  Recommended:,Operating system:,Windows XP/Vist...          $4.99
# 21478  Recommended:,OS:,Windows 7/8/10 (64-bit OS req...          $9.99
# 27056  Recommended:,OS:,Windows 7/8/10 (64-bit OS req...         $19.99
# 27163                                                NaN           Free
# 29208  Recommended:,OS:,Windows 7/8/10 (64-bit OS req...          $4.99
# 29386                                                NaN         $49.99
# 37388  Recommended:,Operating system:,Windows XP/Vist...         $11.99
# 39430  Recommended:,OS:,NVIDIA GTX 470 1GB /AMD HD 78...            NaN
# 40460  Recommended:,OS:,Windows 7/8/10 (64-bit OS req...            NaN
#
#       discount_price Score
# 164              NaN    93
# 202           $38.99    60
# 211              NaN    93
# 337           $38.99    63
# 403           $29.99     0
# 404           $23.99    85
# 405           $14.99    70
# 756              NaN    91
# 805              NaN    87
# 837              NaN    51
# 1159             NaN    65
# 8037             NaN     0
# 9112          $14.99    84
# 11622            NaN     0
# 11623            NaN     0
# 20179            NaN     0
# 21478          $5.99    77
# 27056         $11.99    40
# 27163            NaN    23
# 29208          $2.99     0
# 29386         $24.99    33
# 37388            NaN     0
# 39430            NaN     0
# 40460            NaN     0
#
# [24 rows x 21 columns]

# %% [markdown]
# # Top 10 developers com mais jogos + Gráficos

# %%
developer = pd.DataFrame(data.developer.value_counts().reset_index().values, columns=["Developer", "Quantidade"])
developerindex = developer.sort_index(axis = 0, ascending=True)
developerindex.head(10)
# Out:
#                     Developer Quantidade
# 0     Ubisoft - San Francisco       1041
# 1         SmiteWorks USA, LLC        784
# 2  KOEI TECMO GAMES CO., LTD.        472
# 3              Dovetail Games        217
# 4                         Sly        153
# 5  Paradox Development Studio        140
# 6                      Capcom        129
# 7                   N3V Games        126
# 8            CAPCOM Co., Ltd.        120
# 9             Choice of Games        118

# %% [markdown]
# Tabela Simples

# %%
D = developerindex['Developer'].head(10)
Q = developerindex ['Quantidade'].head(10)

fig = plt.figure(figsize =(10, 7))
plt.bar(D[0:10], Q[0:10])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Tabela mais complexa

# %%
D = developerindex['Developer'].head(10)
Q = developerindex ['Quantidade'].head(10)

fig, ax = plt.subplots(figsize =(16, 9))
 
ax.barh(D, Q)
 

for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 

ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
ax.invert_yaxis()
 
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
ax.set_title('Top Dez Developers com Mais Jogos',
             loc ='left', )

plt.show()

# %% [markdown]
# # Pergunta: Procurar por ano de lançamento

# %%
pergunta = input('Qual o ano de lançamento? ')

### Exemplo: 2007 ###

ano = data['release_date'].str.contains(pergunta, case=False, na=False)
data[ano]
# Out:
# Qual o ano de lançamento? 2007
#                                                      url types  \
# 26        https://store.steampowered.com/app/400/Portal/   app
# 164    https://store.steampowered.com/app/22330/The_E...   app
# 386    https://store.steampowered.com/app/440/Team_Fo...   app
# 424    https://store.steampowered.com/app/4500/STALKE...   app
# 511    https://store.steampowered.com/app/7940/Call_o...   app
# ...                                                  ...   ...
# 31150  https://store.steampowered.com/app/12510/Priso...   app
# 33745  https://store.steampowered.com/app/15930/Luxor_3/   app
# 38093  https://store.steampowered.com/app/498270/Red_...   app
# 39679  https://store.steampowered.com/app/808600/Stre...   app
# 39680  https://store.steampowered.com/app/808590/Stre...   app
#
#                                                     name  \
# 26                                                Portal
# 164    The Elder Scrolls IV: Oblivion® Game of the Ye...
# 386                                      Team Fortress 2
# 424                  S.T.A.L.K.E.R.: Shadow of Chernobyl
# 511                     Call of Duty® 4: Modern Warfare®
# ...                                                  ...
# 31150                         Prison Tycoon 3™: Lockdown
# 33745                                            Luxor 3
# 38093  Red vs. Blue: The Blood Gulch Chronicles (Volu...
# 39679                  Street Fighter Alpha: Generations
# 39680                             Street Fighter Alpha 1
#
#                                             desc_snippet  \
# 26     Portal™ is a new single player game from Valve...
# 164    The Elder Scrolls IV: Oblivion® Game of the Ye...
# 386    Nine distinct classes provide a broad range of...
# 424    S.T.A.L.K.E.R.: Shadow of Chernobyl tells a st...
# 511    The new action-thriller from the award-winning...
# ...                                                  ...
# 31150  Crack that Whip! Take reigns of a privately ru...
# 33745  A brave young Pharaoh, killed prematurely by a...
# 38093  The Blood Gulch Chronicles conclude with the u...
# 39679  When Ryu returns to pay homage to his deceased...
# 39680  Martial arts masters Ken and Ryu are brought t...
#
#                                           recent_reviews  \
# 26     Overwhelmingly Positive,(352),- 98% of the 352...
# 164    Very Positive,(122),- 93% of the 122 user revi...
# 386    Very Positive,(3,526),- 91% of the 3,526 user ...
# 424    Very Positive,(186),- 91% of the 186 user revi...
# 511    Very Positive,(57),- 91% of the 57 user review...
# ...                                                  ...
# 31150                                                NaN
# 33745                                                NaN
# 38093                                                NaN
# 39679                                                NaN
# 39680                                                NaN
#
#                                              all_reviews  release_date  \
# 26     Overwhelmingly Positive,(40,424),- 97% of the ...  Oct 10, 2007
# 164    Very Positive,(11,784),- 94% of the 11,784 use...  Sep 11, 2007
# 386    Very Positive,(553,458),- 93% of the 553,458 u...  Oct 10, 2007
# 424    Very Positive,(9,128),- 94% of the 9,128 user ...  Mar 20, 2007
# 511    Very Positive,(7,518),- 90% of the 7,518 user ...  Nov 12, 2007
# ...                                                  ...           ...
# 31150  Very Negative,(103),- 17% of the 103 user revi...   Aug 1, 2007
# 33745  Positive,(29),- 89% of the 29 user reviews for...  Nov 13, 2007
# 38093                                                NaN   Jan 1, 2007
# 39679                                                NaN   Sep 4, 2007
# 39680                                                NaN   Mar 1, 2007
#
#                          developer  \
# 26                           Valve
# 164          Bethesda Game Studios
# 386                          Valve
# 424                 GSC Game World
# 511      Infinity Ward,Aspyr (Mac)
# ...                            ...
# 31150  Gamebryo,Virtual Playground
# 33745                   MumboJumbo
# 38093    Rooster Teeth Productions
# 39679                          NaN
# 39680                          NaN
#
#                                            publisher  \
# 26                                       Valve,Valve
# 164            Bethesda Softworks,Bethesda Softworks
# 386                                      Valve,Valve
# 424                    GSC Game World,GSC Game World
# 511    Activision,Aspyr (Mac),Activision,Aspyr (Mac)
# ...                                              ...
# 31150            ValuSoft,Retroism,ValuSoft,Retroism
# 33745                          MumboJumbo,MumboJumbo
# 38093                                            NaN
# 39679                                            NaN
# 39680                                            NaN
#
#                                             popular_tags  ...  \
# 26     Puzzle,First-Person,Singleplayer,Sci-fi,Comedy...  ...
# 164    Open World,RPG,Fantasy,Singleplayer,Moddable,F...  ...
# 386    Free to Play,Multiplayer,FPS,Shooter,Action,Cl...  ...
# 424    Atmospheric,Post-apocalyptic,Open World,FPS,Su...  ...
# 511    FPS,Action,Multiplayer,Shooter,First-Person,Cl...  ...
# ...                                                  ...  ...
# 31150                                Strategy,Simulation  ...
# 33745                              Casual,Match 3,Puzzle  ...
# 38093       Comedy,Sci-fi,Fantasy,Movie,Action-Adventure  ...
# 39679                                              Movie  ...
# 39680                                              Movie  ...
#
#                                                languages achievements  \
# 26     English,French,German,Russian,Danish,Dutch,Fin...         15.0
# 164                                              English          NaN
# 386    English,Danish,Dutch,Finnish,French,German,Ita...        520.0
# 424    English,French,Italian,Spanish - Spain,German,...          NaN
# 511        English,French,German,Italian,Spanish - Spain          NaN
# ...                                                  ...          ...
# 31150                                            English          NaN
# 33745                                            English          NaN
# 38093                                            English          NaN
# 39679                     English,French,German,Japanese          NaN
# 39680                            English,German,Japanese          NaN
#
#                      genre                                   game_description  \
# 26                  Action   About This Game  Portal™ is a new single play...
# 164                    RPG   About This Game The Elder Scrolls IV: Oblivio...
# 386    Action,Free to Play   About This Game  "The most fun you can have o...
# 424             Action,RPG   About This Game In 1986, the world's worst nu...
# 511                 Action   About This Game The new action-thriller from ...
# ...                    ...                                                ...
# 31150             Strategy   About This Game Crack that Whip!  Take reigns...
# 33745               Casual   About This Game A brave young Pharaoh, killed...
# 38093                  NaN   About This Video The Blood Gulch Chronicles c...
# 39679                  NaN   About This Video Ryu, Ken, Gouki and Sakura r...
# 39680                  NaN   About This Video Martial arts masters Ken and...
#
#                                           mature_content  \
# 26                                                   NaN
# 164                                                  NaN
# 386     Mature Content Description  The developers de...
# 424                                                  NaN
# 511                                                  NaN
# ...                                                  ...
# 31150                                                NaN
# 33745                                                NaN
# 38093                                                NaN
# 39679                                                NaN
# 39680                                                NaN
#
#                                     minimum_requirements  \
# 26                                                   NaN
# 164                                                  NaN
# 386    Minimum:,OS:,Windows® 7 (32/64-bit)/Vista/XP,P...
# 424    Supported OS:,Microsoft® Windows® XP(Service P...
# 511                                                  NaN
# ...                                                  ...
# 31150                                                NaN
# 33745                                                NaN
# 38093  Minimum:,OS:,Windows 7,Processor:,Intel Core 2...
# 39679  Minimum:,OS:,Windows 7,Processor:,Intel Core 2...
# 39680  Minimum:,OS:,Windows 7,Processor:,Intel Core 2...
#
#                                 recommended_requirements original_price  \
# 26                                                   NaN          $9.99
# 164                                                  NaN         $14.99
# 386    Recommended:,OS:,Windows® 7 (32/64-bit),Proces...   Free to Play
# 424    Supported OS:,Microsoft® Windows® XP/Vista (SP...         $19.99
# 511                                                  NaN          1.020
# ...                                                  ...            ...
# 31150                                                NaN          $9.99
# 33745                                                NaN          $9.99
# 38093  Recommended:,OS:,Windows 10,Processor:,Intel C...          $3.99
# 39679  Recommended:,OS:,Windows 10,Processor:,Intel C...          $2.99
# 39680  Recommended:,OS:,Windows 10,Processor:,Intel C...          $2.99
#
#       discount_price Score
# 26            $14.98    98
# 164              NaN    93
# 386           $65.70    91
# 424              NaN    91
# 511          $906.48    91
# ...              ...   ...
# 31150            NaN     0
# 33745            NaN     0
# 38093         $34.95     0
# 39679            NaN     0
# 39680            NaN     0
#
# [130 rows x 21 columns]

# %% [markdown]
# # Top 10 melhores descontos

# %% [markdown]
# Tirar os simbolos

# %%
data['original_price'] = data['original_price'].str.replace('$','', regex=True)
data['discount_price'] = data['discount_price'].str.replace('$','', regex=True)

data.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags  ...  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...  ...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...  ...
#
#                                            languages achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...         54.0
# 1  English,Korean,Simplified Chinese,French,Germa...         37.0
# 2                      English,French,German,Russian        128.0
# 3  English,French,Italian,German,Spanish - Spain,...          NaN
# 4                      English,German,Russian,French          NaN
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...          19.99
# 1  Recommended:,Requires a 64-bit processor and o...          29.99
# 2  Recommended:,Requires a 64-bit processor and o...          39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...          44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
#
#   discount_price Score
# 0          14.99    89
# 1            NaN    49
# 2            NaN    54
# 3            NaN    57
# 4            NaN    54
#
# [5 rows x 21 columns]

# %% [markdown]
# Por o 'Free' e 'nan' como '0'
# Troca todas as frases restantes para numerico
# Troca todos NaN para '0'

# %%
data['original_price'].replace({"Free": "0"}, inplace=True)
data['original_price'].replace({"Free To Play": "0"}, inplace=True)
data['original_price'].replace({"nan": "0"}, inplace=True)

data['original_price'] = pd.to_numeric(data['original_price'],errors='coerce')
data = data.replace(np.nan, 0, regex=True)


data['original_price'] = data['original_price'].fillna(0)
data['discount_price'] = data['discount_price'].fillna(0)

data.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags  ...  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...  ...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...  ...
#
#                                            languages achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...         54.0
# 1  English,Korean,Simplified Chinese,French,Germa...         37.0
# 2                      English,French,German,Russian        128.0
# 3  English,French,Italian,German,Spanish - Spain,...          0.0
# 4                      English,German,Russian,French          0.0
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                  0
# 1   Mature Content Description  The developers de...
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...          19.99
# 1  Recommended:,Requires a 64-bit processor and o...          29.99
# 2  Recommended:,Requires a 64-bit processor and o...          39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...          44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           0.00
#
#    discount_price Score
# 0           14.99    89
# 1               0    49
# 2               0    54
# 3               0    57
# 4               0    54
#
# [5 rows x 21 columns]

# %% [markdown]
# Passa a coluna de objeto para float

# %%
data['original_price'] = pd.to_numeric(data['original_price'], downcast='float')
data['discount_price'] = pd.to_numeric(data['discount_price'], downcast='float')

data.dtypes
# Out:
# url                          object
# types                        object
# name                         object
# desc_snippet                 object
# recent_reviews               object
# all_reviews                  object
# release_date                 object
# developer                    object
# publisher                    object
# popular_tags                 object
# game_details                 object
# languages                    object
# achievements                float64
# genre                        object
# game_description             object
# mature_content               object
# minimum_requirements         object
# recommended_requirements     object
# original_price              float32
# discount_price              float32
# Score                        object
# dtype: object

# %% [markdown]
# Cria coluna com a diferença de preço

# %%
data['diferenca'] = data.apply(lambda x: x['original_price'] - x['discount_price'], axis=1)

data.head(3)
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
#
#                                         popular_tags  ... achievements  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...         54.0
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...         37.0
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...        128.0
#
#                                     genre  \
# 0                                  Action
# 1  Action,Adventure,Massively Multiplayer
# 2               Action,Adventure,Strategy
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
#
#                                       mature_content  \
# 0                                                  0
# 1   Mature Content Description  The developers de...
# 2                                                  0
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...      19.990000
# 1  Recommended:,Requires a 64-bit processor and o...      29.990000
# 2  Recommended:,Requires a 64-bit processor and o...      39.990002
#
#   discount_price  Score  diferenca
# 0          14.99     89   5.000000
# 1           0.00     49  29.990000
# 2           0.00     54  39.990002
#
# [3 rows x 22 columns]

# %% [markdown]
# Calcular o desconto

# %%
data['desc'] = data['diferenca'] / data['original_price']
data['descontoTotal'] = data['desc'] * 100
data.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags  ...  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...  ...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...  ...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                  0
# 1   Mature Content Description  The developers de...
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...      19.990000
# 1  Recommended:,Requires a 64-bit processor and o...      29.990000
# 2  Recommended:,Requires a 64-bit processor and o...      39.990002
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...      44.990002
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...       0.000000
#
#   discount_price Score  diferenca      desc  descontoTotal
# 0          14.99    89   5.000000  0.250125      25.012507
# 1           0.00    49  29.990000  1.000000     100.000000
# 2           0.00    54  39.990002  1.000000     100.000000
# 3           0.00    57  44.990002  1.000000     100.000000
# 4           0.00    54   0.000000       NaN            NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Retirar os 100 em desconto total

# %%
f = data['descontoTotal']
data.loc[data['descontoTotal'] == 100, 'descontoTotal'] = 0
print(f)
# Out:
# 0        25.012507
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4              NaN
#            ...
# 40828     0.000000
# 40829     0.000000
# 40830     0.000000
# 40831     0.000000
# 40832    43.887774
# Name: descontoTotal, Length: 40833, dtype: float64

# %% [markdown]
# Top 10 Melhores Descontos

# %%
data.nlargest(n=10, columns=['descontoTotal'])
# Out:
#                                                      url types  \
# 38427  https://store.steampowered.com/app/1035680/Pai...   app
# 10556  https://store.steampowered.com/app/982180/Slav...   app
# 11429  https://store.steampowered.com/app/791750/Pres...   app
# 18908  https://store.steampowered.com/app/805500/Dokk...   app
# 21969  https://store.steampowered.com/app/918260/Pach...   app
# 22498  https://store.steampowered.com/app/786670/Loot...   app
# 27581  https://store.steampowered.com/app/802660/Bitc...   app
# 27582  https://store.steampowered.com/app/802650/Russ...   app
# 32311  https://store.steampowered.com/app/917780/Anim...   app
# 38942  https://store.steampowered.com/app/787770/Loot...   app
#
#                                     name  \
# 38427             Pain Train Sound Track
# 10556                        Slave Ghost
# 11429  President Trump The Way In Uganda
# 18908         Dokkaebi Hentai Adventures
# 21969        Pachansky Mathematics 2+2=8
# 22498            Loot Box Simulator 20!8
# 27581                   Bitcoin Or Bomb?
# 27582                   Russian AYE Race
# 32311      Anime Girl Or Boy? Soundtrack
# 38942      Loot Box Simulator 20!8 - OST
#
#                                             desc_snippet recent_reviews  \
# 38427                                                  0              0
# 10556  You play as a ghost slave who runs away from t...              0
# 11429  Once President Trump learned about an ancient ...              0
# 18908  You play for anime-girl with an unusual name D...              0
# 21969  You play as an boy next door from the district...              0
# 22498  Strange simulator for a certain type of people...              0
# 27581  You are playing for the FDB agent (Federal def...              0
# 27582  You are playing for a usual rural Russian guy ...              0
# 32311                                                  0              0
# 38942                                                  0              0
#
#                                              all_reviews  release_date  \
# 38427                                                  0  Feb 21, 2019
# 10556  2 user reviews,- Need more user reviews to gen...  Nov 29, 2018
# 11429  Positive,(49),- 85% of the 49 user reviews for...   Feb 6, 2018
# 18908  Mostly Positive,(12),- 75% of the 12 user revi...  Feb 28, 2018
# 21969  6 user reviews,- Need more user reviews to gen...  Aug 21, 2018
# 22498  Mixed,(12),- 66% of the 12 user reviews for th...  Jan 30, 2018
# 27581  2 user reviews,- Need more user reviews to gen...  Feb 22, 2018
# 27582  3 user reviews,- Need more user reviews to gen...  Feb 22, 2018
# 32311                                                  0  Aug 15, 2018
# 38942                                                  0  Jan 30, 2018
#
#                 developer                        publisher  \
# 38427         Virtual Top      VT Publishing,VT Publishing
# 10556  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 11429  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 18908  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 21969  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 22498  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 27581  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 27582  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 32311  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
# 38942  Nikita "Ghost_RUS"  Ghost_RUS Games,Ghost_RUS Games
#
#                                             popular_tags  ...  \
# 38427  Indie,Casual,Adventure,Gore,Action,Strategy,Vi...  ...
# 10556                             Adventure,Indie,Casual  ...
# 11429                       Indie,Adventure,Casual,Memes  ...
# 18908                Indie,Casual,Adventure,Anime,Nudity  ...
# 21969                            Indie,Casual,Simulation  ...
# 22498                            Indie,Casual,Simulation  ...
# 27581                                       Indie,Casual  ...
# 27582                                Indie,Casual,Racing  ...
# 32311                                       Indie,Casual  ...
# 38942                            Indie,Casual,Simulation  ...
#
#                                         game_description  \
# 38427   About This Content  Pain Train Sound Track A ...
# 10556   About This Game 6969 year, the usual ghost sl...
# 11429   About This Game 2288, President Trump was sit...
# 18908   About This Game Anime-girl Dokkaebi, as usual...
# 21969   About This Game A rovnyi boy Stasian wants to...
# 22498   About This Game 2017, many AAA games began to...
# 27581   About This Game Terrorists plant the bombs th...
# 27582   About This Game 20!8, the usual rural guy Iva...
# 32311   About This Content This DLC include all sound...
# 38942   About This Content This DLC include all sound...
#
#                                           mature_content  \
# 38427   Mature Content Description  The developers de...
# 10556                                                  0
# 11429                                                  0
# 18908                                                  0
# 21969                                                  0
# 22498                                                  0
# 27581                                                  0
# 27582                                                  0
# 32311                                                  0
# 38942                                                  0
#
#        minimum_requirements recommended_requirements original_price  \
# 38427                     0                        0     624.739990
# 10556                     0                        0      96.279999
# 11429                     0                        0      96.279999
# 18908                     0                        0      96.279999
# 21969                     0                        0      96.279999
# 22498                     0                        0      96.279999
# 27581                     0                        0      96.279999
# 27582                     0                        0      96.279999
# 32311                     0                        0      96.279999
# 38942                     0                        0      96.279999
#
#       discount_price Score   diferenca      desc  descontoTotal
# 38427           6.98     0  617.759990  0.988827      98.882735
# 10556           1.18     0   95.099999  0.987744      98.774408
# 11429           1.18     0   95.099999  0.987744      98.774408
# 18908           1.18     0   95.099999  0.987744      98.774408
# 21969           1.18     0   95.099999  0.987744      98.774408
# 22498           1.18     0   95.099999  0.987744      98.774408
# 27581           1.18     0   95.099999  0.987744      98.774408
# 27582           1.18     0   95.099999  0.987744      98.774408
# 32311           1.18     0   95.099999  0.987744      98.774408
# 38942           1.18     0   95.099999  0.987744      98.774408
#
# [10 rows x 24 columns]
